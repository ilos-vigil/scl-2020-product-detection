# %% [markdown]
# ## Library

# %%
import platform
import os
import random
import scipy

import pandas as pd
from sklearn.metrics import f1_score, classification_report
import tensorflow as tf
import tensorflow_addons as tfa
import numpy as np
import sklearn
import gensim
import datetime

# %%
SEED = 42

os.environ['PYTHONHASHSEED']=str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
MAX_WORD = 200
EMBEDDING_DIMENSION = 30

# %%
print('Python version:', platform.python_version())
print('Tensorflow Version:', tf.__version__)
print('Tensorflow Addons Version:', tfa.__version__)
print('Pandas Version:', pd.__version__)
print('Numpy Version:', np.__version__)
print(f'{gensim.__version__=}')
# Out:
# Python version: 3.8.3
# Tensorflow Version: 2.2.0
# Tensorflow Addons Version: 0.10.0
# Pandas Version: 1.0.3
# Numpy Version: 1.18.5
# gensim.__version__='3.8.3'

# %%
gensim.models.fasttext.FAST_VERSION
# Out:
# 1

# %% [markdown]
# ## Dataset

# %%
def to_list(words):
    if words == '[]':
        return []
    else:
        words = words.strip('"')
        words = words.strip('[')
        words = words.strip(']')
        words = words.split(',')
        words = [w.lstrip(' ') for w in words]
        words = [w.strip("'") for w in words]
        words = [w for w in words if w != '']

        return words

# %%
df_train = pd.read_csv('./_csv_with_clean_text/train.min.csv')
df_train['words'] = df_train['words'].apply(to_list)
df_train
# Out:
#                                     filename  category             words
# 0       45e2d0c97f7bdf8cbf3594beb6fdcda0.jpg         3                []
# 1       f74d1a5fc2498bbbfa045c74e3cc333e.jpg         3      [anti, club]
# 2       f6c172096818c5fab10ecae722840798.jpg         3     [door, hello]
# 3       251ffd610399ac00fea7709c642676ee.jpg         3                []
# 4       73c7328b8eda399199fdedec6e4badaf.jpg         3                []
# ...                                      ...       ...               ...
# 105385  047a60001de0331608ba64092cc7ae2b.jpg        25                []
# 105386  ea39ac66ccdc4b4d4c6443f6c54d8ae3.jpg        25  [dunia, fashion]
# 105387  6215f8c52c5bbcfe3e63e0f3ac6265f8.jpg        25                []
# 105388  1733d8286f6658149c7b7cdeb40d6461.jpg        25                []
# 105389  8ee42460e9b6f3d909e32fdef2b6052f.jpg        25                []
#
# [105390 rows x 3 columns]

# %%
df_test = pd.read_csv('./_csv_with_clean_text/test.min.csv')
df_test['words'] = df_test['words'].apply(to_list)
df_test
# Out:
#                                    filename  category  \
# 0      fd663cf2b6e1d7b02938c6aaae0a32d2.jpg        43
# 1      c7fd77508a8c355eaab0d4e10efd6b15.jpg        43
# 2      127f3e6d6e3491b2459812353f33a913.jpg        43
# 3      5ca4f2da11eda083064e6c36f37eeb81.jpg        43
# 4      46d681a542f2c71be017eef6aae23313.jpg        43
# ...                                     ...       ...
# 12181  5ba958eacb23cd7d1673bad4dae55784.jpg        43
# 12182  efbe41a1c2b666b70e337e438559808b.jpg        43
# 12183  79fdaa5ac5ba10dbe8004cabd8c35eb3.jpg        43
# 12184  ac3d136124617637a05ba66694e381ef.jpg        43
# 12185  7ef61d7cfbad9cfe2db4f64560e3dddd.jpg        43
#
#                                                    words
# 0                              [kafe, murah, kiss, meja]
# 1                                          [come, pusat]
# 2                                                 [girl]
# 3                               [sniper, helmets, nails]
# 4                                                     []
# ...                                                  ...
# 12181                                                 []
# 12182                                                 []
# 12183                                   [happy, pumping]
# 12184  [money, back, free, boas, balaga, single, pota...
# 12185                                                 []
#
# [12186 rows x 3 columns]

# %%
X_train = df_train['words'].copy()
X_train = X_train.to_numpy()

y_train = df_train['category'].copy()
y_train = y_train.to_numpy()

X_test = df_test['words'].copy()
X_test = X_test.to_numpy()

y_test = df_test['category'].copy()
y_test = y_test.to_numpy()

# %% [markdown]
# # FastText Embedding

# %%
class EpochLogger(gensim.models.callbacks.CallbackAny2Vec):
    '''Callback to log information about training'''

    def __init__(self):
        self.epoch = 0

    def on_epoch_begin(self, model):
        print(f"Epoch #{self.epoch} start at {datetime.datetime.now()}")

    def on_epoch_end(self, model):
        print(f"Epoch #{self.epoch} end at {datetime.datetime.now()}")
        self.epoch += 1

# %%
model_ft = gensim.models.FastText(X_train, size=EMBEDDING_DIMENSION, window=5, min_count=1, sg=0, hs=0, ns_exponent=0.75, seed=SEED, workers=12, callbacks=[EpochLogger()])
model_ft.train(X_train, total_examples=len(X_train), epochs=15)
# model_ft.save('./dataset/w2v_cbow_ns_min_20.model')
# Out:
# Epoch #0 start at 2020-06-30 18:48:09.228866
# Epoch #0 end at 2020-06-30 18:48:09.619440
# Epoch #1 start at 2020-06-30 18:48:09.619574
# Epoch #1 end at 2020-06-30 18:48:10.014141
# Epoch #2 start at 2020-06-30 18:48:10.014294
# Epoch #2 end at 2020-06-30 18:48:10.371777
# Epoch #3 start at 2020-06-30 18:48:10.371868
# Epoch #3 end at 2020-06-30 18:48:10.741905
# Epoch #4 start at 2020-06-30 18:48:10.742033
# Epoch #4 end at 2020-06-30 18:48:11.097716
# Epoch #5 start at 2020-06-30 18:48:11.391304
# Epoch #5 end at 2020-06-30 18:48:11.807712
# Epoch #6 start at 2020-06-30 18:48:11.807835
# Epoch #6 end at 2020-06-30 18:48:12.186200
# Epoch #7 start at 2020-06-30 18:48:12.186357
# Epoch #7 end at 2020-06-30 18:48:12.557992
# Epoch #8 start at 2020-06-30 18:48:12.558125
# Epoch #8 end at 2020-06-30 18:48:12.932313
# Epoch #9 start at 2020-06-30 18:48:12.932439
# Epoch #9 end at 2020-06-30 18:48:13.289876
# Epoch #10 start at 2020-06-30 18:48:13.289999
# Epoch #10 end at 2020-06-30 18:48:13.704182
# Epoch #11 start at 2020-06-30 18:48:13.704313
# Epoch #11 end at 2020-06-30 18:48:14.103146
# Epoch #12 start at 2020-06-30 18:48:14.103268
# Epoch #12 end at 2020-06-30 18:48:14.481933
# Epoch #13 start at 2020-06-30 18:48:14.482056
# Epoch #13 end at 2020-06-30 18:48:14.874695
# Epoch #14 start at 2020-06-30 18:48:14.874844
# Epoch #14 end at 2020-06-30 18:48:15.226921
# Epoch #15 start at 2020-06-30 18:48:15.227045
# Epoch #15 end at 2020-06-30 18:48:15.596117
# Epoch #16 start at 2020-06-30 18:48:15.596232
# Epoch #16 end at 2020-06-30 18:48:15.972534
# Epoch #17 start at 2020-06-30 18:48:15.972649
# Epoch #17 end at 2020-06-30 18:48:16.341882
# Epoch #18 start at 2020-06-30 18:48:16.342060
# Epoch #18 end at 2020-06-30 18:48:16.699445
# Epoch #19 start at 2020-06-30 18:48:16.699584
# Epoch #19 end at 2020-06-30 18:48:17.096682

# %%
model_ft.wv.vocab
# Out:
# {'anti': <gensim.models.keyedvectors.Vocab at 0x7f52056e7b50>,
#  'club': <gensim.models.keyedvectors.Vocab at 0x7f520855fcd0>,
#  'door': <gensim.models.keyedvectors.Vocab at 0x7f5202fe0910>,
#  'hello': <gensim.models.keyedvectors.Vocab at 0x7f5202fe08b0>,
#  'miss': <gensim.models.keyedvectors.Vocab at 0x7f5202fe09d0>,
#  'sled': <gensim.models.keyedvectors.Vocab at 0x7f5202fe0a30>,
#  'dogs': <gensim.models.keyedvectors.Vocab at 0x7f5202fe07c0>,
#  'dong': <gensim.models.keyedvectors.Vocab at 0x7f5202fe0ac0>,
#  'plan': <gensim.models.keyedvectors.Vocab at 0x7f5202fe0b50>,
#  'ones': <gensim.models.keyedvectors.Vocab at 0x7f5202fe0bb0>,
#  'plain': <gensim.models.keyedvectors.Vocab at 0x7f5202fe0be0>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x7f5202fe0c40>,
#  'ten': <gensim.models.keyedvectors.Vocab at 0x7f5202fe0ca0>,
#  'staff': <gensim.models.keyedvectors.Vocab at 0x7f5202fe0d00>,
#  'pose': <gensim.models.keyedvectors.Vocab at 0x7f5202fe0d90>,
#  'gain': <gensim.models.keyedvectors.Vocab at 0x7f5202fe0df0>,
#  'navy': <gensim.models.keyedvectors.Vocab at 0x7f5202fe0e20>,
#  'shoot': <gensim.models.keyedvectors.Vocab at 0x7f5202fe0eb0>,
#  'open': <gensim.models.keyedvectors.Vocab at 0x7f5202fe0f10>,
#  'mains': <gensim.models.keyedvectors.Vocab at 0x7f5202fe0f70>,
#  'pour': <gensim.models.keyedvectors.Vocab at 0x7f5202fe0fd0>,
#  'mud': <gensim.models.keyedvectors.Vocab at 0x7f5202fe0e80>,
#  'coat': <gensim.models.keyedvectors.Vocab at 0x7f52b461ba60>,
#  'becher': <gensim.models.keyedvectors.Vocab at 0x7f52b461b130>,
#  'hijau': <gensim.models.keyedvectors.Vocab at 0x7f52b461b700>,
#  'botol': <gensim.models.keyedvectors.Vocab at 0x7f52b461b070>,
#  'pink': <gensim.models.keyedvectors.Vocab at 0x7f52b460fd30>,
#  'put': <gensim.models.keyedvectors.Vocab at 0x7f5205715460>,
#  'baby': <gensim.models.keyedvectors.Vocab at 0x7f52057151c0>,
#  'kuning': <gensim.models.keyedvectors.Vocab at 0x7f52057150a0>,
#  'maroon': <gensim.models.keyedvectors.Vocab at 0x7f5205715430>,
#  'ukuran': <gensim.models.keyedvectors.Vocab at 0x7f52057153d0>,
#  'dada': <gensim.models.keyedvectors.Vocab at 0x7f5205715580>,
#  'lebar': <gensim.models.keyedvectors.Vocab at 0x7f5205715280>,
#  'sing': <gensim.models.keyedvectors.Vocab at 0x7f52057152e0>,
#  'double': <gensim.models.keyedvectors.Vocab at 0x7f5205715340>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x7f5205715190>,
#  'run': <gensim.models.keyedvectors.Vocab at 0x7f5202fed070>,
#  'kraft': <gensim.models.keyedvectors.Vocab at 0x7f5202fed0d0>,
#  'factors': <gensim.models.keyedvectors.Vocab at 0x7f5202fed130>,
#  'pony': <gensim.models.keyedvectors.Vocab at 0x7f5202fed190>,
#  'putih': <gensim.models.keyedvectors.Vocab at 0x7f5202fed1f0>,
#  'room': <gensim.models.keyedvectors.Vocab at 0x7f5202fed250>,
#  'muda': <gensim.models.keyedvectors.Vocab at 0x7f5202fed2b0>,
#  'burgundy': <gensim.models.keyedvectors.Vocab at 0x7f5202fed310>,
#  'orange': <gensim.models.keyedvectors.Vocab at 0x7f5202fed3a0>,
#  'turkish': <gensim.models.keyedvectors.Vocab at 0x7f5202fed400>,
#  'army': <gensim.models.keyedvectors.Vocab at 0x7f5202fed460>,
#  'flat': <gensim.models.keyedvectors.Vocab at 0x7f5202fed4c0>,
#  'hitam': <gensim.models.keyedvectors.Vocab at 0x7f5202fed520>,
#  'detail': <gensim.models.keyedvectors.Vocab at 0x7f5202fed580>,
#  'knit': <gensim.models.keyedvectors.Vocab at 0x7f5202fed610>,
#  'hoodie': <gensim.models.keyedvectors.Vocab at 0x7f5202fed340>,
#  'unisex': <gensim.models.keyedvectors.Vocab at 0x7f5202fed6a0>,
#  'jumper': <gensim.models.keyedvectors.Vocab at 0x7f5202fed6d0>,
#  'best': <gensim.models.keyedvectors.Vocab at 0x7f5202fed730>,
#  'seller': <gensim.models.keyedvectors.Vocab at 0x7f5202fed790>,
#  'cried': <gensim.models.keyedvectors.Vocab at 0x7f5202fed7f0>,
#  'gray': <gensim.models.keyedvectors.Vocab at 0x7f5202fed850>,
#  'express': <gensim.models.keyedvectors.Vocab at 0x7f5202fed8b0>,
#  'sizes': <gensim.models.keyedvectors.Vocab at 0x7f5202fed970>,
#  'send': <gensim.models.keyedvectors.Vocab at 0x7f5202feda00>,
#  'tribal': <gensim.models.keyedvectors.Vocab at 0x7f5202feda60>,
#  'black': <gensim.models.keyedvectors.Vocab at 0x7f5202fedac0>,
#  'tebal': <gensim.models.keyedvectors.Vocab at 0x7f5202fedb20>,
#  'rajut': <gensim.models.keyedvectors.Vocab at 0x7f5202fedb80>,
#  'ungu': <gensim.models.keyedvectors.Vocab at 0x7f5202fedbe0>,
#  'dusty': <gensim.models.keyedvectors.Vocab at 0x7f5202fed8e0>,
#  'touch': <gensim.models.keyedvectors.Vocab at 0x7f5202fedc70>,
#  'yellow': <gensim.models.keyedvectors.Vocab at 0x7f5202fedcd0>,
#  'sunny': <gensim.models.keyedvectors.Vocab at 0x7f5202fedd30>,
#  'mint': <gensim.models.keyedvectors.Vocab at 0x7f5202fedd90>,
#  'back': <gensim.models.keyedvectors.Vocab at 0x7f5202feddf0>,
#  'love': <gensim.models.keyedvectors.Vocab at 0x7f5202fede50>,
#  'coast': <gensim.models.keyedvectors.Vocab at 0x7f5202fedeb0>,
#  'pans': <gensim.models.keyedvectors.Vocab at 0x7f5202fed910>,
#  'aris': <gensim.models.keyedvectors.Vocab at 0x7f5202fedf70>,
#  'paris': <gensim.models.keyedvectors.Vocab at 0x7f5202fed9d0>,
#  'paus': <gensim.models.keyedvectors.Vocab at 0x7f5202fedee0>,
#  'bone': <gensim.models.keyedvectors.Vocab at 0x7f5202ff2070>,
#  'pari': <gensim.models.keyedvectors.Vocab at 0x7f5202ff20d0>,
#  'pitta': <gensim.models.keyedvectors.Vocab at 0x7f5202ff2130>,
#  'blaster': <gensim.models.keyedvectors.Vocab at 0x7f5202ff2190>,
#  'bite': <gensim.models.keyedvectors.Vocab at 0x7f5202ff21f0>,
#  'ran': <gensim.models.keyedvectors.Vocab at 0x7f5202ff2250>,
#  'fear': <gensim.models.keyedvectors.Vocab at 0x7f5202ff22b0>,
#  'monster': <gensim.models.keyedvectors.Vocab at 0x7f5202ff2310>,
#  'blue': <gensim.models.keyedvectors.Vocab at 0x7f5202ff2370>,
#  'khaki': <gensim.models.keyedvectors.Vocab at 0x7f5202ff23d0>,
#  'white': <gensim.models.keyedvectors.Vocab at 0x7f5202ff2430>,
#  'japan': <gensim.models.keyedvectors.Vocab at 0x7f5202ff2490>,
#  'lost': <gensim.models.keyedvectors.Vocab at 0x7f5202ff24f0>,
#  'management': <gensim.models.keyedvectors.Vocab at 0x7f5202ff2550>,
#  'real': <gensim.models.keyedvectors.Vocab at 0x7f5202ff25b0>,
#  'picture': <gensim.models.keyedvectors.Vocab at 0x7f5202ff2610>,
#  'sweater': <gensim.models.keyedvectors.Vocab at 0x7f5202ff2670>,
#  'sablon': <gensim.models.keyedvectors.Vocab at 0x7f5202ff26d0>,
#  'full': <gensim.models.keyedvectors.Vocab at 0x7f5202ff2700>,
#  'misty': <gensim.models.keyedvectors.Vocab at 0x7f5202ff2790>,
#  'salem': <gensim.models.keyedvectors.Vocab at 0x7f5202ff27f0>,
#  'kubus': <gensim.models.keyedvectors.Vocab at 0x7f5202ff2850>,
#  'polos': <gensim.models.keyedvectors.Vocab at 0x7f5202ff28b0>,
#  'caramel': <gensim.models.keyedvectors.Vocab at 0x7f5202ff2910>,
#  'emerald': <gensim.models.keyedvectors.Vocab at 0x7f5202ff2970>,
#  'cream': <gensim.models.keyedvectors.Vocab at 0x7f5202ff29d0>,
#  'silver': <gensim.models.keyedvectors.Vocab at 0x7f5202ff2a60>,
#  'york': <gensim.models.keyedvectors.Vocab at 0x7f5202ff2ac0>,
#  'flee': <gensim.models.keyedvectors.Vocab at 0x7f5202ff2b20>,
#  'perfect': <gensim.models.keyedvectors.Vocab at 0x7f5202ff2b80>,
#  'bant': <gensim.models.keyedvectors.Vocab at 0x7f5202ff2be0>,
#  'stars': <gensim.models.keyedvectors.Vocab at 0x7f5202ff2c40>,
#  'size': <gensim.models.keyedvectors.Vocab at 0x7f5202ff2ca0>,
#  'terlaris': <gensim.models.keyedvectors.Vocab at 0x7f5202ff2d00>,
#  'made': <gensim.models.keyedvectors.Vocab at 0x7f5202ff2d60>,
#  'slim': <gensim.models.keyedvectors.Vocab at 0x7f5202ff2dc0>,
#  'avocado': <gensim.models.keyedvectors.Vocab at 0x7f5202ff2e20>,
#  'krem': <gensim.models.keyedvectors.Vocab at 0x7f5202ff2e80>,
#  'peach': <gensim.models.keyedvectors.Vocab at 0x7f5202ff2ee0>,
#  'bronze': <gensim.models.keyedvectors.Vocab at 0x7f5202ff2f40>,
#  'check': <gensim.models.keyedvectors.Vocab at 0x7f5202ff2fa0>,
#  'king': <gensim.models.keyedvectors.Vocab at 0x7f5202ff2a30>,
#  'fashion': <gensim.models.keyedvectors.Vocab at 0x7f5202fdc070>,
#  'pembayaran': <gensim.models.keyedvectors.Vocab at 0x7f5202fdc0d0>,
#  'pembeli': <gensim.models.keyedvectors.Vocab at 0x7f5202fdc130>,
#  'metode': <gensim.models.keyedvectors.Vocab at 0x7f5202fdc190>,
#  'thrasher': <gensim.models.keyedvectors.Vocab at 0x7f5202fdc1f0>,
#  'order': <gensim.models.keyedvectors.Vocab at 0x7f5202fdc250>,
#  'zipper': <gensim.models.keyedvectors.Vocab at 0x7f5202fdc2b0>,
#  'klik': <gensim.models.keyedvectors.Vocab at 0x7f5202fdc2e0>,
#  'sesuai': <gensim.models.keyedvectors.Vocab at 0x7f5202fdc370>,
#  'warna': <gensim.models.keyedvectors.Vocab at 0x7f5202fdc3d0>,
#  'lihat': <gensim.models.keyedvectors.Vocab at 0x7f5202fdc430>,
#  'catatan': <gensim.models.keyedvectors.Vocab at 0x7f5202fdc490>,
#  'pesanan': <gensim.models.keyedvectors.Vocab at 0x7f5202fdc4f0>,
#  'pemesanan': <gensim.models.keyedvectors.Vocab at 0x7f5202fdc550>,
#  'pengiriman': <gensim.models.keyedvectors.Vocab at 0x7f5202fdc5b0>,
#  'selesai': <gensim.models.keyedvectors.Vocab at 0x7f5202fdc610>,
#  'penilaian': <gensim.models.keyedvectors.Vocab at 0x7f5202fdc6a0>,
#  'penjual': <gensim.models.keyedvectors.Vocab at 0x7f5202fdc700>,
#  'wold': <gensim.models.keyedvectors.Vocab at 0x7f5202fdc760>,
#  'year': <gensim.models.keyedvectors.Vocab at 0x7f5202fdc7c0>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x7f5202fdc820>,
#  'cant': <gensim.models.keyedvectors.Vocab at 0x7f5202fdc880>,
#  'home': <gensim.models.keyedvectors.Vocab at 0x7f5202fdc8e0>,
#  'companion': <gensim.models.keyedvectors.Vocab at 0x7f5202fdc640>,
#  'outbox': <gensim.models.keyedvectors.Vocab at 0x7f5202fdc970>,
#  'vegetal': <gensim.models.keyedvectors.Vocab at 0x7f5202fdc9d0>,
#  'laun': <gensim.models.keyedvectors.Vocab at 0x7f5202fdca30>,
#  'thrift': <gensim.models.keyedvectors.Vocab at 0x7f5202fdca90>,
#  'standard': <gensim.models.keyedvectors.Vocab at 0x7f5202fdcaf0>,
#  'able': <gensim.models.keyedvectors.Vocab at 0x7f5202fdcb50>,
#  'raft': <gensim.models.keyedvectors.Vocab at 0x7f5202fdcbb0>,
#  'plus': <gensim.models.keyedvectors.Vocab at 0x7f5202fdcc10>,
#  'diskon': <gensim.models.keyedvectors.Vocab at 0x7f5202fdcc70>,
#  'quality': <gensim.models.keyedvectors.Vocab at 0x7f5202fdccd0>,
#  'truth': <gensim.models.keyedvectors.Vocab at 0x7f5202fdcd30>,
#  'light': <gensim.models.keyedvectors.Vocab at 0x7f5202fdcd90>,
#  'clear': <gensim.models.keyedvectors.Vocab at 0x7f5202fdcdf0>,
#  'lite': <gensim.models.keyedvectors.Vocab at 0x7f5202fdce50>,
#  'doit': <gensim.models.keyedvectors.Vocab at 0x7f5202fdceb0>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x7f5202fdcf10>,
#  'ware': <gensim.models.keyedvectors.Vocab at 0x7f5202fdcf70>,
#  'fila': <gensim.models.keyedvectors.Vocab at 0x7f5202fdcfd0>,
#  'fragile': <gensim.models.keyedvectors.Vocab at 0x7f5202fd8070>,
#  'asked': <gensim.models.keyedvectors.Vocab at 0x7f5202fd80d0>,
#  'told': <gensim.models.keyedvectors.Vocab at 0x7f5202fd8130>,
#  'fantastic': <gensim.models.keyedvectors.Vocab at 0x7f5202fd8190>,
#  'woman': <gensim.models.keyedvectors.Vocab at 0x7f5202fd81f0>,
#  'fast': <gensim.models.keyedvectors.Vocab at 0x7f5202fd8250>,
#  'delivery': <gensim.models.keyedvectors.Vocab at 0x7f5202fd82b0>,
#  'original': <gensim.models.keyedvectors.Vocab at 0x7f5202fd8310>,
#  'ready': <gensim.models.keyedvectors.Vocab at 0x7f5202fd8370>,
#  'stock': <gensim.models.keyedvectors.Vocab at 0x7f5202fd83d0>,
#  'pets': <gensim.models.keyedvectors.Vocab at 0x7f5202fd8430>,
#  'bandung': <gensim.models.keyedvectors.Vocab at 0x7f5202fd8490>,
#  'australia': <gensim.models.keyedvectors.Vocab at 0x7f5202fd84f0>,
#  'nota': <gensim.models.keyedvectors.Vocab at 0x7f5202fd8550>,
#  'live': <gensim.models.keyedvectors.Vocab at 0x7f5202fd85b0>,
#  'khusus': <gensim.models.keyedvectors.Vocab at 0x7f5202fd8610>,
#  'berat': <gensim.models.keyedvectors.Vocab at 0x7f5202fd8670>,
#  'jump': <gensim.models.keyedvectors.Vocab at 0x7f5202fd86d0>,
#  'meow': <gensim.models.keyedvectors.Vocab at 0x7f5202fd8730>,
#  'bahan': <gensim.models.keyedvectors.Vocab at 0x7f5202fd8790>,
#  'says': <gensim.models.keyedvectors.Vocab at 0x7f5202fd87f0>,
#  'coco': <gensim.models.keyedvectors.Vocab at 0x7f5202fd8850>,
#  'stripe': <gensim.models.keyedvectors.Vocab at 0x7f5202fd88b0>,
#  'hope': <gensim.models.keyedvectors.Vocab at 0x7f5202fd8910>,
#  'icon': <gensim.models.keyedvectors.Vocab at 0x7f5202fd8970>,
#  'cotton': <gensim.models.keyedvectors.Vocab at 0x7f5202fd89d0>,
#  'bust': <gensim.models.keyedvectors.Vocab at 0x7f5202fd8a30>,
#  'length': <gensim.models.keyedvectors.Vocab at 0x7f5202fd8a90>,
#  'shoulder': <gensim.models.keyedvectors.Vocab at 0x7f5202fd8af0>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x7f5202fd8b50>,
#  'medium': <gensim.models.keyedvectors.Vocab at 0x7f5202fd8bb0>,
#  'store': <gensim.models.keyedvectors.Vocab at 0x7f5202fd8c10>,
#  'side': <gensim.models.keyedvectors.Vocab at 0x7f5202fd8c70>,
#  'cookie': <gensim.models.keyedvectors.Vocab at 0x7f5202fd8cd0>,
#  'lavender': <gensim.models.keyedvectors.Vocab at 0x7f5202fd8d30>,
#  'dark': <gensim.models.keyedvectors.Vocab at 0x7f5202fd8d90>,
#  'biru': <gensim.models.keyedvectors.Vocab at 0x7f5202fd8df0>,
#  'elektrik': <gensim.models.keyedvectors.Vocab at 0x7f5202fd8e50>,
#  'denim': <gensim.models.keyedvectors.Vocab at 0x7f5202fd8eb0>,
#  'mocha': <gensim.models.keyedvectors.Vocab at 0x7f5202fd8f10>,
#  'magenta': <gensim.models.keyedvectors.Vocab at 0x7f5202fd8f70>,
#  'merah': <gensim.models.keyedvectors.Vocab at 0x7f5202fd8fd0>,
#  'lime': <gensim.models.keyedvectors.Vocab at 0x7f5202fd9070>,
#  'took': <gensim.models.keyedvectors.Vocab at 0x7f5202fd90d0>,
#  'mustard': <gensim.models.keyedvectors.Vocab at 0x7f5202fd9130>,
#  'coral': <gensim.models.keyedvectors.Vocab at 0x7f5202fd9190>,
#  'lake': <gensim.models.keyedvectors.Vocab at 0x7f5202fd91f0>,
#  'chest': <gensim.models.keyedvectors.Vocab at 0x7f5202fd9250>,
#  'basic': <gensim.models.keyedvectors.Vocab at 0x7f5202fd92b0>,
#  'keep': <gensim.models.keyedvectors.Vocab at 0x7f5202fd9310>,
#  'calm': <gensim.models.keyedvectors.Vocab at 0x7f5202fd9370>,
#  'carry': <gensim.models.keyedvectors.Vocab at 0x7f5202fd93d0>,
#  'toko': <gensim.models.keyedvectors.Vocab at 0x7f5202fd9430>,
#  'ongkos': <gensim.models.keyedvectors.Vocab at 0x7f5202fd9490>,
#  'kirim': <gensim.models.keyedvectors.Vocab at 0x7f5202fd94f0>,
#  'suka': <gensim.models.keyedvectors.Vocab at 0x7f5202fd9550>,
#  'garansi': <gensim.models.keyedvectors.Vocab at 0x7f5202fd95b0>,
#  'kami': <gensim.models.keyedvectors.Vocab at 0x7f5202fd9610>,
#  'terima': <gensim.models.keyedvectors.Vocab at 0x7f5202fd9670>,
#  'panduan': <gensim.models.keyedvectors.Vocab at 0x7f5202fd96d0>,
#  'beli': <gensim.models.keyedvectors.Vocab at 0x7f5202fd9730>,
#  'pares': <gensim.models.keyedvectors.Vocab at 0x7f5202fd9790>,
#  'flash': <gensim.models.keyedvectors.Vocab at 0x7f5202fd97f0>,
#  'sale': <gensim.models.keyedvectors.Vocab at 0x7f5202fd9850>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x7f5202fd98b0>,
#  'limited': <gensim.models.keyedvectors.Vocab at 0x7f5202fd9910>,
#  'lepas': <gensim.models.keyedvectors.Vocab at 0x7f5202fd9970>,
#  'parka': <gensim.models.keyedvectors.Vocab at 0x7f5202fd99d0>,
#  'tasha': <gensim.models.keyedvectors.Vocab at 0x7f5202fd9a30>,
#  'women': <gensim.models.keyedvectors.Vocab at 0x7f5202fd9a90>,
#  'mats': <gensim.models.keyedvectors.Vocab at 0x7f5202fd9af0>,
#  'sac': <gensim.models.keyedvectors.Vocab at 0x7f5202fd9b50>,
#  'design': <gensim.models.keyedvectors.Vocab at 0x7f5202fd9bb0>,
#  'custom': <gensim.models.keyedvectors.Vocab at 0x7f5202fd9c10>,
#  'royal': <gensim.models.keyedvectors.Vocab at 0x7f5202fd9c70>,
#  'shoe': <gensim.models.keyedvectors.Vocab at 0x7f5202fd9cd0>,
#  'town': <gensim.models.keyedvectors.Vocab at 0x7f5202fd9d30>,
#  'honey': <gensim.models.keyedvectors.Vocab at 0x7f5202fd9d90>,
#  'bear': <gensim.models.keyedvectors.Vocab at 0x7f5202fd9df0>,
#  'cats': <gensim.models.keyedvectors.Vocab at 0x7f5202fd9e50>,
#  'fleece': <gensim.models.keyedvectors.Vocab at 0x7f5202fd9eb0>,
#  'dear': <gensim.models.keyedvectors.Vocab at 0x7f5202fd9f10>,
#  'nanas': <gensim.models.keyedvectors.Vocab at 0x7f5202fd9f70>,
#  'social': <gensim.models.keyedvectors.Vocab at 0x7f5202fd9fd0>,
#  'suss': <gensim.models.keyedvectors.Vocab at 0x7f5202fd7070>,
#  'seas': <gensim.models.keyedvectors.Vocab at 0x7f5202fd70d0>,
#  'popcorn': <gensim.models.keyedvectors.Vocab at 0x7f5202fd7130>,
#  'gourmet': <gensim.models.keyedvectors.Vocab at 0x7f5202fd7190>,
#  'seven': <gensim.models.keyedvectors.Vocab at 0x7f5202fd71f0>,
#  'arrivals': <gensim.models.keyedvectors.Vocab at 0x7f5202fd7250>,
#  'photo': <gensim.models.keyedvectors.Vocab at 0x7f5202fd72b0>,
#  'style': <gensim.models.keyedvectors.Vocab at 0x7f5202fd7310>,
#  'studio': <gensim.models.keyedvectors.Vocab at 0x7f5202fd7370>,
#  'heart': <gensim.models.keyedvectors.Vocab at 0x7f5202fd73d0>,
#  'house': <gensim.models.keyedvectors.Vocab at 0x7f5202fd7430>,
#  'kopi': <gensim.models.keyedvectors.Vocab at 0x7f5202fd7490>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x7f5202fd74f0>,
#  'salur': <gensim.models.keyedvectors.Vocab at 0x7f5202fd7550>,
#  'avenue': <gensim.models.keyedvectors.Vocab at 0x7f5202fd75b0>,
#  'cele': <gensim.models.keyedvectors.Vocab at 0x7f5202fd7610>,
#  'place': <gensim.models.keyedvectors.Vocab at 0x7f5202fd7670>,
#  'caste': <gensim.models.keyedvectors.Vocab at 0x7f5202fd76d0>,
#  'mimi': <gensim.models.keyedvectors.Vocab at 0x7f5202fd7730>,
#  'site': <gensim.models.keyedvectors.Vocab at 0x7f5202fd7790>,
#  'collection': <gensim.models.keyedvectors.Vocab at 0x7f5202fd77f0>,
#  'mall': <gensim.models.keyedvectors.Vocab at 0x7f5202fd7850>,
#  'hero': <gensim.models.keyedvectors.Vocab at 0x7f5202fd78b0>,
#  'checkout': <gensim.models.keyedvectors.Vocab at 0x7f5202fd7910>,
#  'lupa': <gensim.models.keyedvectors.Vocab at 0x7f5202fd7970>,
#  'tulis': <gensim.models.keyedvectors.Vocab at 0x7f5202fd79d0>,
#  'pesan': <gensim.models.keyedvectors.Vocab at 0x7f5202fd7a30>,
#  'opsi': <gensim.models.keyedvectors.Vocab at 0x7f5202fd7a90>,
#  'yang': <gensim.models.keyedvectors.Vocab at 0x7f5202fd7af0>,
#  'diterima': <gensim.models.keyedvectors.Vocab at 0x7f5202fd7b50>,
#  'total': <gensim.models.keyedvectors.Vocab at 0x7f5202fd7bb0>,
#  'produce': <gensim.models.keyedvectors.Vocab at 0x7f5202fd7c10>,
#  'voucher': <gensim.models.keyedvectors.Vocab at 0x7f5202fd7c70>,
#  'kode': <gensim.models.keyedvectors.Vocab at 0x7f5202fd7cd0>,
#  'transfer': <gensim.models.keyedvectors.Vocab at 0x7f5202fd7d30>,
#  'bank': <gensim.models.keyedvectors.Vocab at 0x7f5202fd7d90>,
#  'subtotal': <gensim.models.keyedvectors.Vocab at 0x7f5202fd7df0>,
#  'produk': <gensim.models.keyedvectors.Vocab at 0x7f5202fd7e50>,
#  'ring': <gensim.models.keyedvectors.Vocab at 0x7f5202fd7eb0>,
#  'cocci': <gensim.models.keyedvectors.Vocab at 0x7f5202fd7f10>,
#  'premium': <gensim.models.keyedvectors.Vocab at 0x7f52b4613250>,
#  'cells': <gensim.models.keyedvectors.Vocab at 0x7f5202fd7f70>,
#  'choice': <gensim.models.keyedvectors.Vocab at 0x7f5202fd7fd0>,
#  'gratis': <gensim.models.keyedvectors.Vocab at 0x7f5202fe5070>,
#  'indonesia': <gensim.models.keyedvectors.Vocab at 0x7f5202fe50d0>,
#  'sher': <gensim.models.keyedvectors.Vocab at 0x7f5202fe5130>,
#  'creamy': <gensim.models.keyedvectors.Vocab at 0x7f5202fe5190>,
#  'destroy': <gensim.models.keyedvectors.Vocab at 0x7f5202fe51f0>,
#  'supreme': <gensim.models.keyedvectors.Vocab at 0x7f5202fe5250>,
#  'rome': <gensim.models.keyedvectors.Vocab at 0x7f5202fe52b0>,
#  'foes': <gensim.models.keyedvectors.Vocab at 0x7f5202fe5310>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x7f5202fe5370>,
#  'keterangan': <gensim.models.keyedvectors.Vocab at 0x7f5202fe53d0>,
#  'silakan': <gensim.models.keyedvectors.Vocab at 0x7f5202fe5430>,
#  'dice': <gensim.models.keyedvectors.Vocab at 0x7f5202fe5490>,
#  'koin': <gensim.models.keyedvectors.Vocab at 0x7f5202fe54f0>,
#  'didapatkan': <gensim.models.keyedvectors.Vocab at 0x7f5202fe5550>,
#  'skin': <gensim.models.keyedvectors.Vocab at 0x7f5202fe55b0>,
#  'rout': <gensim.models.keyedvectors.Vocab at 0x7f5202fe5610>,
#  'promises': <gensim.models.keyedvectors.Vocab at 0x7f5202fe5670>,
#  'even': <gensim.models.keyedvectors.Vocab at 0x7f5202fe56d0>,
#  'shed': <gensim.models.keyedvectors.Vocab at 0x7f5202fe5730>,
#  'hell': <gensim.models.keyedvectors.Vocab at 0x7f5202fe5790>,
#  'game': <gensim.models.keyedvectors.Vocab at 0x7f5202fe57f0>,
#  'animation': <gensim.models.keyedvectors.Vocab at 0x7f5202fe5850>,
#  'men': <gensim.models.keyedvectors.Vocab at 0x7f5202fe58b0>,
#  'small': <gensim.models.keyedvectors.Vocab at 0x7f5202fe5910>,
#  'stop': <gensim.models.keyedvectors.Vocab at 0x7f5202fe5970>,
#  'never': <gensim.models.keyedvectors.Vocab at 0x7f5202fe59d0>,
#  'spot': <gensim.models.keyedvectors.Vocab at 0x7f5202fe5a30>,
#  'reseller': <gensim.models.keyedvectors.Vocab at 0x7f5202fe5a90>,
#  'forest': <gensim.models.keyedvectors.Vocab at 0x7f5202fe5af0>,
#  'price': <gensim.models.keyedvectors.Vocab at 0x7f5202fe5b50>,
#  'nothing': <gensim.models.keyedvectors.Vocab at 0x7f5202fe5bb0>,
#  'rules': <gensim.models.keyedvectors.Vocab at 0x7f5202fe5c10>,
#  'heroes': <gensim.models.keyedvectors.Vocab at 0x7f5202fe5c70>,
#  'pron': <gensim.models.keyedvectors.Vocab at 0x7f5202fe5cd0>,
#  'whats': <gensim.models.keyedvectors.Vocab at 0x7f5202fe5d30>,
#  'give': <gensim.models.keyedvectors.Vocab at 0x7f5202fe5d90>,
#  'test': <gensim.models.keyedvectors.Vocab at 0x7f5202fe5df0>,
#  'soup': <gensim.models.keyedvectors.Vocab at 0x7f5202fe5e50>,
#  'yous': <gensim.models.keyedvectors.Vocab at 0x7f5202fe5eb0>,
#  'sweet': <gensim.models.keyedvectors.Vocab at 0x7f5202fe5f10>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x7f5202fe5f70>,
#  'cold': <gensim.models.keyedvectors.Vocab at 0x7f5202fe5fd0>,
#  'salon': <gensim.models.keyedvectors.Vocab at 0x7f5202fea070>,
#  'wings': <gensim.models.keyedvectors.Vocab at 0x7f5202fea0d0>,
#  'another': <gensim.models.keyedvectors.Vocab at 0x7f5202fea130>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x7f5202fea190>,
#  'noon': <gensim.models.keyedvectors.Vocab at 0x7f5202fea1f0>,
#  'version': <gensim.models.keyedvectors.Vocab at 0x7f5202fea250>,
#  'bring': <gensim.models.keyedvectors.Vocab at 0x7f5202fea2b0>,
#  'stone': <gensim.models.keyedvectors.Vocab at 0x7f5202fea310>,
#  'toleransi': <gensim.models.keyedvectors.Vocab at 0x7f5202fea370>,
#  'soul': <gensim.models.keyedvectors.Vocab at 0x7f5202fea3d0>,
#  'lining': <gensim.models.keyedvectors.Vocab at 0x7f5202fea430>,
#  'import': <gensim.models.keyedvectors.Vocab at 0x7f5202fea490>,
#  'kaos': <gensim.models.keyedvectors.Vocab at 0x7f5202fea4f0>,
#  'bordir': <gensim.models.keyedvectors.Vocab at 0x7f5202fea550>,
#  'darn': <gensim.models.keyedvectors.Vocab at 0x7f5202fea5b0>,
#  'daisy': <gensim.models.keyedvectors.Vocab at 0x7f5202fea610>,
#  'series': <gensim.models.keyedvectors.Vocab at 0x7f5202fea670>,
#  'resmi': <gensim.models.keyedvectors.Vocab at 0x7f5202fea6d0>,
#  'chat': <gensim.models.keyedvectors.Vocab at 0x7f5202fea730>,
#  'lead': <gensim.models.keyedvectors.Vocab at 0x7f5202fea790>,
#  'mason': <gensim.models.keyedvectors.Vocab at 0x7f5202fea7f0>,
#  'data': <gensim.models.keyedvectors.Vocab at 0x7f5202fea850>,
#  'brown': <gensim.models.keyedvectors.Vocab at 0x7f5202fea8b0>,
#  'boots': <gensim.models.keyedvectors.Vocab at 0x7f5202fea910>,
#  'tong': <gensim.models.keyedvectors.Vocab at 0x7f5202fea970>,
#  'family': <gensim.models.keyedvectors.Vocab at 0x7f5202fea9d0>,
#  'happy': <gensim.models.keyedvectors.Vocab at 0x7f5202feaa30>,
#  'likes': <gensim.models.keyedvectors.Vocab at 0x7f5202feaa90>,
#  'free': <gensim.models.keyedvectors.Vocab at 0x7f5202feaaf0>,
#  'strength': <gensim.models.keyedvectors.Vocab at 0x7f5202feab50>,
#  'outer': <gensim.models.keyedvectors.Vocab at 0x7f5202feabb0>,
#  'milo': <gensim.models.keyedvectors.Vocab at 0x7f5202feac10>,
#  'doubt': <gensim.models.keyedvectors.Vocab at 0x7f5202feac70>,
#  'rare': <gensim.models.keyedvectors.Vocab at 0x7f5202feacd0>,
#  'variasi': <gensim.models.keyedvectors.Vocab at 0x7f5202fead30>,
#  'mini': <gensim.models.keyedvectors.Vocab at 0x7f5202fead90>,
#  'latte': <gensim.models.keyedvectors.Vocab at 0x7f5202feadf0>,
#  'fail': <gensim.models.keyedvectors.Vocab at 0x7f5202feae50>,
#  'line': <gensim.models.keyedvectors.Vocab at 0x7f5202feaeb0>,
#  'material': <gensim.models.keyedvectors.Vocab at 0x7f5202feaf10>,
#  'green': <gensim.models.keyedvectors.Vocab at 0x7f5202feaf70>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x7f5202feafd0>,
#  'rain': <gensim.models.keyedvectors.Vocab at 0x7f5202fee070>,
#  'living': <gensim.models.keyedvectors.Vocab at 0x7f5202fee0d0>,
#  'sunshine': <gensim.models.keyedvectors.Vocab at 0x7f5202fee130>,
#  'pace': <gensim.models.keyedvectors.Vocab at 0x7f5202fee190>,
#  'times': <gensim.models.keyedvectors.Vocab at 0x7f5202fee1f0>,
#  'pocky': <gensim.models.keyedvectors.Vocab at 0x7f5202fee250>,
#  'nary': <gensim.models.keyedvectors.Vocab at 0x7f5202fee2b0>,
#  'multi': <gensim.models.keyedvectors.Vocab at 0x7f5202fee310>,
#  'fish': <gensim.models.keyedvectors.Vocab at 0x7f5202fee370>,
#  'morning': <gensim.models.keyedvectors.Vocab at 0x7f5202fee3d0>,
#  'selfie': <gensim.models.keyedvectors.Vocab at 0x7f5202fee430>,
#  'bomber': <gensim.models.keyedvectors.Vocab at 0x7f5202fee490>,
#  'sales': <gensim.models.keyedvectors.Vocab at 0x7f5202fee4f0>,
#  'sens': <gensim.models.keyedvectors.Vocab at 0x7f5202fee550>,
#  'eyes': <gensim.models.keyedvectors.Vocab at 0x7f5202fee5b0>,
#  'aren': <gensim.models.keyedvectors.Vocab at 0x7f5202fee610>,
#  'olive': <gensim.models.keyedvectors.Vocab at 0x7f5202fee670>,
#  'pase': <gensim.models.keyedvectors.Vocab at 0x7f5202fee6d0>,
#  'utih': <gensim.models.keyedvectors.Vocab at 0x7f5202fee730>,
#  'paul': <gensim.models.keyedvectors.Vocab at 0x7f5202fee790>,
#  'core': <gensim.models.keyedvectors.Vocab at 0x7f5202fee7f0>,
#  'show': <gensim.models.keyedvectors.Vocab at 0x7f5202fee850>,
#  'nice': <gensim.models.keyedvectors.Vocab at 0x7f5202fee8b0>,
#  'lovely': <gensim.models.keyedvectors.Vocab at 0x7f5202fee910>,
#  'guns': <gensim.models.keyedvectors.Vocab at 0x7f5202fee970>,
#  'shop': <gensim.models.keyedvectors.Vocab at 0x7f5202fee9d0>,
#  'terbaru': <gensim.models.keyedvectors.Vocab at 0x7f5202feea30>,
#  'cook': <gensim.models.keyedvectors.Vocab at 0x7f5202feea90>,
#  'stable': <gensim.models.keyedvectors.Vocab at 0x7f5202feeaf0>,
#  'lengan': <gensim.models.keyedvectors.Vocab at 0x7f5202feeb50>,
#  'boxy': <gensim.models.keyedvectors.Vocab at 0x7f5202feebb0>,
#  'bata': <gensim.models.keyedvectors.Vocab at 0x7f5202feec10>,
#  'cute': <gensim.models.keyedvectors.Vocab at 0x7f5202feec70>,
#  'reserve': <gensim.models.keyedvectors.Vocab at 0x7f5202feecd0>,
#  'rabbit': <gensim.models.keyedvectors.Vocab at 0x7f5202feed30>,
#  'reds': <gensim.models.keyedvectors.Vocab at 0x7f5202feed90>,
#  'mama': <gensim.models.keyedvectors.Vocab at 0x7f5202feedf0>,
#  'grew': <gensim.models.keyedvectors.Vocab at 0x7f5202feee50>,
#  'cinnamon': <gensim.models.keyedvectors.Vocab at 0x7f5202feeeb0>,
#  'neon': <gensim.models.keyedvectors.Vocab at 0x7f5202feef10>,
#  'grosir': <gensim.models.keyedvectors.Vocab at 0x7f5202feef70>,
#  'jaket': <gensim.models.keyedvectors.Vocab at 0x7f5202feefd0>,
#  'pule': <gensim.models.keyedvectors.Vocab at 0x7f5202fe8070>,
#  'collat': <gensim.models.keyedvectors.Vocab at 0x7f5202fe80d0>,
#  'leban': <gensim.models.keyedvectors.Vocab at 0x7f5202fe8130>,
#  'arrival': <gensim.models.keyedvectors.Vocab at 0x7f5202fe8190>,
#  'peak': <gensim.models.keyedvectors.Vocab at 0x7f5202fe81f0>,
#  'street': <gensim.models.keyedvectors.Vocab at 0x7f5202fe8250>,
#  'create': <gensim.models.keyedvectors.Vocab at 0x7f5202fe82b0>,
#  'generation': <gensim.models.keyedvectors.Vocab at 0x7f5202fe8310>,
#  'kings': <gensim.models.keyedvectors.Vocab at 0x7f5202fe8370>,
#  'sandcastle': <gensim.models.keyedvectors.Vocab at 0x7f5202fe83d0>,
#  'seri': <gensim.models.keyedvectors.Vocab at 0x7f5202fe8430>,
#  'slop': <gensim.models.keyedvectors.Vocab at 0x7f5202fe8490>,
#  'kemeja': <gensim.models.keyedvectors.Vocab at 0x7f5202fe84f0>,
#  'pria': <gensim.models.keyedvectors.Vocab at 0x7f5202fe8550>,
#  'katun': <gensim.models.keyedvectors.Vocab at 0x7f5202fe85b0>,
#  'stretch': <gensim.models.keyedvectors.Vocab at 0x7f5202fe8610>,
#  'bang': <gensim.models.keyedvectors.Vocab at 0x7f5202fe8670>,
#  'shopping': <gensim.models.keyedvectors.Vocab at 0x7f5202fe86d0>,
#  'photography': <gensim.models.keyedvectors.Vocab at 0x7f5202fe8730>,
#  'memo': <gensim.models.keyedvectors.Vocab at 0x7f5202fe8790>,
#  'selera': <gensim.models.keyedvectors.Vocab at 0x7f5202fe87f0>,
#  'attractive': <gensim.models.keyedvectors.Vocab at 0x7f5202fe8850>,
#  'self': <gensim.models.keyedvectors.Vocab at 0x7f5202fe88b0>,
#  'dead': <gensim.models.keyedvectors.Vocab at 0x7f5202fe8910>,
#  'almost': <gensim.models.keyedvectors.Vocab at 0x7f5202fe8970>,
#  'words': <gensim.models.keyedvectors.Vocab at 0x7f5202fe89d0>,
#  'three': <gensim.models.keyedvectors.Vocab at 0x7f5202fe8a30>,
#  'eight': <gensim.models.keyedvectors.Vocab at 0x7f5202fe8a90>,
#  'sick': <gensim.models.keyedvectors.Vocab at 0x7f5202fe8af0>,
#  'footprints': <gensim.models.keyedvectors.Vocab at 0x7f5202fe8b50>,
#  'gaming': <gensim.models.keyedvectors.Vocab at 0x7f5202fe8bb0>,
#  'strong': <gensim.models.keyedvectors.Vocab at 0x7f5202fe8c10>,
#  'wearing': <gensim.models.keyedvectors.Vocab at 0x7f5202fe8c70>,
#  'clean': <gensim.models.keyedvectors.Vocab at 0x7f5202fe8cd0>,
#  'planet': <gensim.models.keyedvectors.Vocab at 0x7f5202fe8d30>,
#  'tour': <gensim.models.keyedvectors.Vocab at 0x7f5202fe8d90>,
#  'speak': <gensim.models.keyedvectors.Vocab at 0x7f5202fe8df0>,
#  'city': <gensim.models.keyedvectors.Vocab at 0x7f5202fe8e50>,
#  'clay': <gensim.models.keyedvectors.Vocab at 0x7f5202fe8eb0>,
#  'dove': <gensim.models.keyedvectors.Vocab at 0x7f5202fe8f10>,
#  'available': <gensim.models.keyedvectors.Vocab at 0x7f5202fe8f70>,
#  'thick': <gensim.models.keyedvectors.Vocab at 0x7f5202fe8fd0>,
#  'elastic': <gensim.models.keyedvectors.Vocab at 0x7f5202fef070>,
#  'goes': <gensim.models.keyedvectors.Vocab at 0x7f5202fef0d0>,
#  'paint': <gensim.models.keyedvectors.Vocab at 0x7f5202fef130>,
#  'sat': <gensim.models.keyedvectors.Vocab at 0x7f5202fef190>,
#  'face': <gensim.models.keyedvectors.Vocab at 0x7f5202fef1f0>,
#  'tail': <gensim.models.keyedvectors.Vocab at 0x7f5202fef250>,
#  'thickness': <gensim.models.keyedvectors.Vocab at 0x7f5202fef2b0>,
#  'aero': <gensim.models.keyedvectors.Vocab at 0x7f5202fef310>,
#  'hind': <gensim.models.keyedvectors.Vocab at 0x7f5202fef370>,
#  'deal': <gensim.models.keyedvectors.Vocab at 0x7f5202fef3d0>,
#  'brew': <gensim.models.keyedvectors.Vocab at 0x7f5202fef430>,
#  'smell': <gensim.models.keyedvectors.Vocab at 0x7f5202fef490>,
#  'roses': <gensim.models.keyedvectors.Vocab at 0x7f5202fef4f0>,
#  'shot': <gensim.models.keyedvectors.Vocab at 0x7f5202fef550>,
#  'candy': <gensim.models.keyedvectors.Vocab at 0x7f5202fef5b0>,
#  'front': <gensim.models.keyedvectors.Vocab at 0x7f5202fef610>,
#  'violet': <gensim.models.keyedvectors.Vocab at 0x7f5202fef670>,
#  'round': <gensim.models.keyedvectors.Vocab at 0x7f5202fef6d0>,
#  'hand': <gensim.models.keyedvectors.Vocab at 0x7f5202fef730>,
#  'found': <gensim.models.keyedvectors.Vocab at 0x7f5202fef790>,
#  'beige': <gensim.models.keyedvectors.Vocab at 0x7f5202fef7f0>,
#  'input': <gensim.models.keyedvectors.Vocab at 0x7f5202fef850>,
#  'dibeli': <gensim.models.keyedvectors.Vocab at 0x7f5202fef8b0>,
#  'else': <gensim.models.keyedvectors.Vocab at 0x7f5202fef910>,
#  'cappuccino': <gensim.models.keyedvectors.Vocab at 0x7f5202fef970>,
#  'espresso': <gensim.models.keyedvectors.Vocab at 0x7f5202fef9d0>,
#  'freedom': <gensim.models.keyedvectors.Vocab at 0x7f5202fefa30>,
#  'lungs': <gensim.models.keyedvectors.Vocab at 0x7f5202fefa90>,
#  'atom': <gensim.models.keyedvectors.Vocab at 0x7f5202fefaf0>,
#  'grow': <gensim.models.keyedvectors.Vocab at 0x7f5202fefb50>,
#  'coal': <gensim.models.keyedvectors.Vocab at 0x7f5202fefbb0>,
#  'tire': <gensim.models.keyedvectors.Vocab at 0x7f5202fefc10>,
#  'halus': <gensim.models.keyedvectors.Vocab at 0x7f5202fefc70>,
#  'see': <gensim.models.keyedvectors.Vocab at 0x7f5202fefcd0>,
#  'aven': <gensim.models.keyedvectors.Vocab at 0x7f5202fefd30>,
#  'years': <gensim.models.keyedvectors.Vocab at 0x7f5202fefd90>,
#  'clot': <gensim.models.keyedvectors.Vocab at 0x7f5202fefdf0>,
#  'tree': <gensim.models.keyedvectors.Vocab at 0x7f5202fefe50>,
#  'sir': <gensim.models.keyedvectors.Vocab at 0x7f5202fefeb0>,
#  'jacket': <gensim.models.keyedvectors.Vocab at 0x7f5202feff10>,
#  'designed': <gensim.models.keyedvectors.Vocab at 0x7f5202feff70>,
#  'rein': <gensim.models.keyedvectors.Vocab at 0x7f5202feffd0>,
#  'attention': <gensim.models.keyedvectors.Vocab at 0x7f5202fe3070>,
#  'une': <gensim.models.keyedvectors.Vocab at 0x7f5202fe30d0>,
#  'inside': <gensim.models.keyedvectors.Vocab at 0x7f5202fe3130>,
#  'title': <gensim.models.keyedvectors.Vocab at 0x7f5202fe3190>,
#  'coffee': <gensim.models.keyedvectors.Vocab at 0x7f5202fe31f0>,
#  'cake': <gensim.models.keyedvectors.Vocab at 0x7f5202fe3250>,
#  'wedges': <gensim.models.keyedvectors.Vocab at 0x7f5202fe32b0>,
#  'pocket': <gensim.models.keyedvectors.Vocab at 0x7f5202fe3310>,
#  'blazer': <gensim.models.keyedvectors.Vocab at 0x7f5202fe3370>,
#  'special': <gensim.models.keyedvectors.Vocab at 0x7f5202fe33d0>,
#  'offers': <gensim.models.keyedvectors.Vocab at 0x7f5202fe3430>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x7f5202fe3490>,
#  'hot': <gensim.models.keyedvectors.Vocab at 0x7f5202fe34f0>,
#  'china': <gensim.models.keyedvectors.Vocab at 0x7f5202fe3550>,
#  'natura': <gensim.models.keyedvectors.Vocab at 0x7f5202fe35b0>,
#  'ling': <gensim.models.keyedvectors.Vocab at 0x7f5202fe3610>,
#  'man': <gensim.models.keyedvectors.Vocab at 0x7f5202fe3670>,
#  'acts': <gensim.models.keyedvectors.Vocab at 0x7f5202fe36d0>,
#  'female': <gensim.models.keyedvectors.Vocab at 0x7f5202fe3730>,
#  'share': <gensim.models.keyedvectors.Vocab at 0x7f5202fe3790>,
#  'league': <gensim.models.keyedvectors.Vocab at 0x7f5202fe37f0>,
#  'delicious': <gensim.models.keyedvectors.Vocab at 0x7f5202fe3850>,
#  'banana': <gensim.models.keyedvectors.Vocab at 0x7f5202fe38b0>,
#  'flower': <gensim.models.keyedvectors.Vocab at 0x7f5202fe3910>,
#  'wall': <gensim.models.keyedvectors.Vocab at 0x7f5202fe3970>,
#  'lumut': <gensim.models.keyedvectors.Vocab at 0x7f5202fe39d0>,
#  'longer': <gensim.models.keyedvectors.Vocab at 0x7f5202fe3a30>,
#  'lies': <gensim.models.keyedvectors.Vocab at 0x7f5202fe3a90>,
#  'friends': <gensim.models.keyedvectors.Vocab at 0x7f5202fe3af0>,
#  'money': <gensim.models.keyedvectors.Vocab at 0x7f5202fe3b50>,
#  'five': <gensim.models.keyedvectors.Vocab at 0x7f5202fe3bb0>,
#  'colors': <gensim.models.keyedvectors.Vocab at 0x7f5202fe3c10>,
#  'done': <gensim.models.keyedvectors.Vocab at 0x7f5202fe3c70>,
#  'cases': <gensim.models.keyedvectors.Vocab at 0x7f5202fe3cd0>,
#  'woes': <gensim.models.keyedvectors.Vocab at 0x7f5202fe3d30>,
#  'rices': <gensim.models.keyedvectors.Vocab at 0x7f5202fe3d90>,
#  'shine': <gensim.models.keyedvectors.Vocab at 0x7f5202fe3df0>,
#  'tali': <gensim.models.keyedvectors.Vocab at 0x7f5202fe3e50>,
#  'tangan': <gensim.models.keyedvectors.Vocab at 0x7f5202fe3eb0>,
#  'sano': <gensim.models.keyedvectors.Vocab at 0x7f5202fe3f10>,
#  'blast': <gensim.models.keyedvectors.Vocab at 0x7f5202fe3f70>,
#  'wear': <gensim.models.keyedvectors.Vocab at 0x7f5202fe3fd0>,
#  'goon': <gensim.models.keyedvectors.Vocab at 0x7f5202e9f070>,
#  'girl': <gensim.models.keyedvectors.Vocab at 0x7f5202e9f0d0>,
#  'rainbow': <gensim.models.keyedvectors.Vocab at 0x7f5202e9f130>,
#  'kitty': <gensim.models.keyedvectors.Vocab at 0x7f5202e9f190>,
#  'sleeve': <gensim.models.keyedvectors.Vocab at 0x7f5202e9f1f0>,
#  'sloe': <gensim.models.keyedvectors.Vocab at 0x7f5202e9f250>,
#  'facial': <gensim.models.keyedvectors.Vocab at 0x7f5202e9f2b0>,
#  'heres': <gensim.models.keyedvectors.Vocab at 0x7f5202e9f310>,
#  'beer': <gensim.models.keyedvectors.Vocab at 0x7f5202e9f370>,
#  'gros': <gensim.models.keyedvectors.Vocab at 0x7f5202e9f3d0>,
#  'stat': <gensim.models.keyedvectors.Vocab at 0x7f5202e9f430>,
#  'enter': <gensim.models.keyedvectors.Vocab at 0x7f5202e9f490>,
#  'news': <gensim.models.keyedvectors.Vocab at 0x7f5202e9f4f0>,
#  'clothing': <gensim.models.keyedvectors.Vocab at 0x7f5202e9f550>,
#  'mode': <gensim.models.keyedvectors.Vocab at 0x7f5202e9f5b0>,
#  'pride': <gensim.models.keyedvectors.Vocab at 0x7f5202e9f610>,
#  'sole': <gensim.models.keyedvectors.Vocab at 0x7f5202e9f670>,
#  'chart': <gensim.models.keyedvectors.Vocab at 0x7f5202e9f6d0>,
#  'hale': <gensim.models.keyedvectors.Vocab at 0x7f5202e9f730>,
#  'warrior': <gensim.models.keyedvectors.Vocab at 0x7f5202e9f790>,
#  'word': <gensim.models.keyedvectors.Vocab at 0x7f5202e9f7f0>,
#  'flow': <gensim.models.keyedvectors.Vocab at 0x7f5202e9f850>,
#  'jumbo': <gensim.models.keyedvectors.Vocab at 0x7f5202e9f8b0>,
#  'super': <gensim.models.keyedvectors.Vocab at 0x7f5202e9f910>,
#  'exclusive': <gensim.models.keyedvectors.Vocab at 0x7f5202e9f970>,
#  'purple': <gensim.models.keyedvectors.Vocab at 0x7f5202e9f9d0>,
#  'list': <gensim.models.keyedvectors.Vocab at 0x7f5202e9fa30>,
#  'malta': <gensim.models.keyedvectors.Vocab at 0x7f5202e9fa90>,
#  'promo': <gensim.models.keyedvectors.Vocab at 0x7f5202e9faf0>,
#  'murah': <gensim.models.keyedvectors.Vocab at 0x7f5202e9fb50>,
#  'mon': <gensim.models.keyedvectors.Vocab at 0x7f5202e9fbb0>,
#  'tone': <gensim.models.keyedvectors.Vocab at 0x7f5202e9fc10>,
#  'name': <gensim.models.keyedvectors.Vocab at 0x7f5202e9fc70>,
#  'atasan': <gensim.models.keyedvectors.Vocab at 0x7f5202e9fcd0>,
#  'turtle': <gensim.models.keyedvectors.Vocab at 0x7f5202e9fd30>,
#  'used': <gensim.models.keyedvectors.Vocab at 0x7f5202e9fd90>,
#  'sono': <gensim.models.keyedvectors.Vocab at 0x7f5202e9fdf0>,
#  'sons': <gensim.models.keyedvectors.Vocab at 0x7f5202e9fe50>,
#  'roma': <gensim.models.keyedvectors.Vocab at 0x7f5202e9feb0>,
#  'ting': <gensim.models.keyedvectors.Vocab at 0x7f5202e9ff10>,
#  'lock': <gensim.models.keyedvectors.Vocab at 0x7f5202e9ff70>,
#  'warm': <gensim.models.keyedvectors.Vocab at 0x7f5202e9ffd0>,
#  'comfortable': <gensim.models.keyedvectors.Vocab at 0x7f5202ea4070>,
#  'protect': <gensim.models.keyedvectors.Vocab at 0x7f5202ea40d0>,
#  'young': <gensim.models.keyedvectors.Vocab at 0x7f5202ea4130>,
#  'lazy': <gensim.models.keyedvectors.Vocab at 0x7f5202ea4190>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x7f5202ea41f0>,
#  'patch': <gensim.models.keyedvectors.Vocab at 0x7f5202ea4250>,
#  'inches': <gensim.models.keyedvectors.Vocab at 0x7f5202ea42b0>,
#  'panda': <gensim.models.keyedvectors.Vocab at 0x7f5202ea4310>,
#  'paper': <gensim.models.keyedvectors.Vocab at 0x7f5202ea4370>,
#  'blow': <gensim.models.keyedvectors.Vocab at 0x7f5202ea43d0>,
#  'person': <gensim.models.keyedvectors.Vocab at 0x7f5202ea4430>,
#  'avengers': <gensim.models.keyedvectors.Vocab at 0x7f5202ea4490>,
#  'whatever': <gensim.models.keyedvectors.Vocab at 0x7f5202ea44f0>,
#  'forever': <gensim.models.keyedvectors.Vocab at 0x7f5202ea4550>,
#  'clothes': <gensim.models.keyedvectors.Vocab at 0x7f5202ea45b0>,
#  'opening': <gensim.models.keyedvectors.Vocab at 0x7f5202ea4610>,
#  'answer': <gensim.models.keyedvectors.Vocab at 0x7f5202ea4670>,
#  'greeted': <gensim.models.keyedvectors.Vocab at 0x7f5202ea46d0>,
#  'focus': <gensim.models.keyedvectors.Vocab at 0x7f5202ea4730>,
#  'come': <gensim.models.keyedvectors.Vocab at 0x7f5202ea4790>,
#  'walk': <gensim.models.keyedvectors.Vocab at 0x7f5202ea47f0>,
#  'stand': <gensim.models.keyedvectors.Vocab at 0x7f5202ea4850>,
#  'brave': <gensim.models.keyedvectors.Vocab at 0x7f5202ea48b0>,
#  'alone': <gensim.models.keyedvectors.Vocab at 0x7f5202ea4910>,
#  'reference': <gensim.models.keyedvectors.Vocab at 0x7f5202ea4970>,
#  'trad': <gensim.models.keyedvectors.Vocab at 0x7f5202ea49d0>,
#  'capital': <gensim.models.keyedvectors.Vocab at 0x7f5202ea4a30>,
#  'outfit': <gensim.models.keyedvectors.Vocab at 0x7f5202ea4a90>,
#  'carol': <gensim.models.keyedvectors.Vocab at 0x7f5202ea4af0>,
#  'tain': <gensim.models.keyedvectors.Vocab at 0x7f5202ea4b50>,
#  'talk': <gensim.models.keyedvectors.Vocab at 0x7f5202ea4bb0>,
#  'fest': <gensim.models.keyedvectors.Vocab at 0x7f5202ea4c10>,
#  'century': <gensim.models.keyedvectors.Vocab at 0x7f5202ea4c70>,
#  'renes': <gensim.models.keyedvectors.Vocab at 0x7f5202ea4cd0>,
#  'supernova': <gensim.models.keyedvectors.Vocab at 0x7f5202ea4d30>,
#  'means': <gensim.models.keyedvectors.Vocab at 0x7f5202ea4d90>,
#  'ever': <gensim.models.keyedvectors.Vocab at 0x7f5202ea4df0>,
#  'slit': <gensim.models.keyedvectors.Vocab at 0x7f5202ea4e50>,
#  'trend': <gensim.models.keyedvectors.Vocab at 0x7f5202ea4eb0>,
#  'production': <gensim.models.keyedvectors.Vocab at 0x7f5202ea4f10>,
#  'director': <gensim.models.keyedvectors.Vocab at 0x7f5202ea4f70>,
#  'camera': <gensim.models.keyedvectors.Vocab at 0x7f5202ea4fd0>,
#  'date': <gensim.models.keyedvectors.Vocab at 0x7f5202ea7070>,
#  'scene': <gensim.models.keyedvectors.Vocab at 0x7f5202ea70d0>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x7f5202ea7130>,
#  'sofa': <gensim.models.keyedvectors.Vocab at 0x7f5202ea7190>,
#  'anta': <gensim.models.keyedvectors.Vocab at 0x7f5202ea71f0>,
#  'boom': <gensim.models.keyedvectors.Vocab at 0x7f5202ea7250>,
#  'port': <gensim.models.keyedvectors.Vocab at 0x7f5202ea72b0>,
#  'crop': <gensim.models.keyedvectors.Vocab at 0x7f5202ea7310>,
#  'lingkar': <gensim.models.keyedvectors.Vocab at 0x7f5202ea7370>,
#  'network': <gensim.models.keyedvectors.Vocab at 0x7f5202ea73d0>,
#  'walking': <gensim.models.keyedvectors.Vocab at 0x7f5202ea7430>,
#  'ariel': <gensim.models.keyedvectors.Vocab at 0x7f5202ea7490>,
#  'notes': <gensim.models.keyedvectors.Vocab at 0x7f5202ea74f0>,
#  'capsule': <gensim.models.keyedvectors.Vocab at 0x7f5202ea7550>,
#  'role': <gensim.models.keyedvectors.Vocab at 0x7f5202ea75b0>,
#  'bits': <gensim.models.keyedvectors.Vocab at 0x7f5202ea7610>,
#  'trial': <gensim.models.keyedvectors.Vocab at 0x7f5202ea7670>,
#  'fall': <gensim.models.keyedvectors.Vocab at 0x7f5202ea76d0>,
#  'color': <gensim.models.keyedvectors.Vocab at 0x7f5202ea7730>,
#  'parking': <gensim.models.keyedvectors.Vocab at 0x7f5202ea7790>,
#  'unique': <gensim.models.keyedvectors.Vocab at 0x7f5202ea77f0>,
#  'puma': <gensim.models.keyedvectors.Vocab at 0x7f5202ea7850>,
#  'kids': <gensim.models.keyedvectors.Vocab at 0x7f5202ea78b0>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x7f5202ea7910>,
#  'trace': <gensim.models.keyedvectors.Vocab at 0x7f5202ea7970>,
#  'mang': <gensim.models.keyedvectors.Vocab at 0x7f5202ea79d0>,
#  'cola': <gensim.models.keyedvectors.Vocab at 0x7f5202ea7a30>,
#  'merry': <gensim.models.keyedvectors.Vocab at 0x7f5202ea7a90>,
#  'success': <gensim.models.keyedvectors.Vocab at 0x7f5202ea7af0>,
#  'part': <gensim.models.keyedvectors.Vocab at 0x7f5202ea7b50>,
#  'application': <gensim.models.keyedvectors.Vocab at 0x7f5202ea7bb0>,
#  'came': <gensim.models.keyedvectors.Vocab at 0x7f5202ea7c10>,
#  'scuba': <gensim.models.keyedvectors.Vocab at 0x7f5202ea7c70>,
#  'boto': <gensim.models.keyedvectors.Vocab at 0x7f5202ea7cd0>,
#  'hole': <gensim.models.keyedvectors.Vocab at 0x7f5202ea7d30>,
#  'lie': <gensim.models.keyedvectors.Vocab at 0x7f5202ea7d90>,
#  'toes': <gensim.models.keyedvectors.Vocab at 0x7f5202ea7df0>,
#  'elder': <gensim.models.keyedvectors.Vocab at 0x7f5202ea7e50>,
#  'percaya': <gensim.models.keyedvectors.Vocab at 0x7f5202ea7eb0>,
#  'cepat': <gensim.models.keyedvectors.Vocab at 0x7f5202ea7f10>,
#  'bayar': <gensim.models.keyedvectors.Vocab at 0x7f5202ea7f70>,
#  'sang': <gensim.models.keyedvectors.Vocab at 0x7f5202ea7fd0>,
#  'deskripsi': <gensim.models.keyedvectors.Vocab at 0x7f5202ea9070>,
#  'baju': <gensim.models.keyedvectors.Vocab at 0x7f5202ea90d0>,
#  'cont': <gensim.models.keyedvectors.Vocab at 0x7f5202ea9130>,
#  'let': <gensim.models.keyedvectors.Vocab at 0x7f5202ea9190>,
#  'nest': <gensim.models.keyedvectors.Vocab at 0x7f5202ea91f0>,
#  'saint': <gensim.models.keyedvectors.Vocab at 0x7f5202ea9250>,
#  'spark': <gensim.models.keyedvectors.Vocab at 0x7f5202ea92b0>,
#  'studios': <gensim.models.keyedvectors.Vocab at 0x7f5202ea9310>,
#  'unite': <gensim.models.keyedvectors.Vocab at 0x7f5202ea9370>,
#  'eater': <gensim.models.keyedvectors.Vocab at 0x7f5202ea93d0>,
#  'wanita': <gensim.models.keyedvectors.Vocab at 0x7f5202ea9430>,
#  'pretty': <gensim.models.keyedvectors.Vocab at 0x7f5202ea9490>,
#  'danger': <gensim.models.keyedvectors.Vocab at 0x7f5202ea94f0>,
#  'less': <gensim.models.keyedvectors.Vocab at 0x7f5202ea9550>,
#  'tare': <gensim.models.keyedvectors.Vocab at 0x7f5202ea95b0>,
#  'sizing': <gensim.models.keyedvectors.Vocab at 0x7f5202ea9610>,
#  'pale': <gensim.models.keyedvectors.Vocab at 0x7f5202ea9670>,
#  'none': <gensim.models.keyedvectors.Vocab at 0x7f5202ea96d0>,
#  'hike': <gensim.models.keyedvectors.Vocab at 0x7f5202ea9730>,
#  'varsity': <gensim.models.keyedvectors.Vocab at 0x7f5202ea9790>,
#  'baseball': <gensim.models.keyedvectors.Vocab at 0x7f5202ea97f0>,
#  'lee': <gensim.models.keyedvectors.Vocab at 0x7f5202ea9850>,
#  'tins': <gensim.models.keyedvectors.Vocab at 0x7f5202ea98b0>,
#  'funny': <gensim.models.keyedvectors.Vocab at 0x7f5202ea9910>,
#  'marry': <gensim.models.keyedvectors.Vocab at 0x7f5202ea9970>,
#  'anna': <gensim.models.keyedvectors.Vocab at 0x7f5202ea99d0>,
#  'sate': <gensim.models.keyedvectors.Vocab at 0x7f5202ea9a30>,
#  'smile': <gensim.models.keyedvectors.Vocab at 0x7f5202ea9a90>,
#  'retro': <gensim.models.keyedvectors.Vocab at 0x7f5202ea9af0>,
#  'jeep': <gensim.models.keyedvectors.Vocab at 0x7f5202ea9b50>,
#  'watch': <gensim.models.keyedvectors.Vocab at 0x7f5202ea9bb0>,
#  'connection': <gensim.models.keyedvectors.Vocab at 0x7f5202ea9c10>,
#  'power': <gensim.models.keyedvectors.Vocab at 0x7f5202ea9c70>,
#  'pain': <gensim.models.keyedvectors.Vocab at 0x7f5202ea9cd0>,
#  'center': <gensim.models.keyedvectors.Vocab at 0x7f5202ea9d30>,
#  'winter': <gensim.models.keyedvectors.Vocab at 0x7f5202ea9d90>,
#  'north': <gensim.models.keyedvectors.Vocab at 0x7f5202ea9df0>,
#  'bund': <gensim.models.keyedvectors.Vocab at 0x7f5202ea9e50>,
#  'cons': <gensim.models.keyedvectors.Vocab at 0x7f5202ea9eb0>,
#  'spirit': <gensim.models.keyedvectors.Vocab at 0x7f5202ea9f10>,
#  'plaster': <gensim.models.keyedvectors.Vocab at 0x7f5202ea9f70>,
#  'iso': <gensim.models.keyedvectors.Vocab at 0x7f5202ea9fd0>,
#  'kinfolk': <gensim.models.keyedvectors.Vocab at 0x7f5202eaa070>,
#  'content': <gensim.models.keyedvectors.Vocab at 0x7f5202eaa0d0>,
#  'okay': <gensim.models.keyedvectors.Vocab at 0x7f5202eaa130>,
#  'peat': <gensim.models.keyedvectors.Vocab at 0x7f5202eaa190>,
#  'playboy': <gensim.models.keyedvectors.Vocab at 0x7f5202eaa1f0>,
#  'champion': <gensim.models.keyedvectors.Vocab at 0x7f5202eaa250>,
#  'soka': <gensim.models.keyedvectors.Vocab at 0x7f5202eaa2b0>,
#  'universal': <gensim.models.keyedvectors.Vocab at 0x7f5202eaa310>,
#  'prod': <gensim.models.keyedvectors.Vocab at 0x7f5202eaa370>,
#  'siat': <gensim.models.keyedvectors.Vocab at 0x7f5202eaa3d0>,
#  'alas': <gensim.models.keyedvectors.Vocab at 0x7f5202eaa430>,
#  'conte': <gensim.models.keyedvectors.Vocab at 0x7f5202eaa490>,
#  'sera': <gensim.models.keyedvectors.Vocab at 0x7f5202eaa4f0>,
#  'ding': <gensim.models.keyedvectors.Vocab at 0x7f5202eaa550>,
#  'couple': <gensim.models.keyedvectors.Vocab at 0x7f5202eaa5b0>,
#  'value': <gensim.models.keyedvectors.Vocab at 0x7f5202eaa610>,
#  'read': <gensim.models.keyedvectors.Vocab at 0x7f5202eaa670>,
#  'shoo': <gensim.models.keyedvectors.Vocab at 0x7f5202eaa6d0>,
#  'enjoy': <gensim.models.keyedvectors.Vocab at 0x7f5202eaa730>,
#  'loon': <gensim.models.keyedvectors.Vocab at 0x7f5202eaa790>,
#  'brand': <gensim.models.keyedvectors.Vocab at 0x7f5202eaa7f0>,
#  'eter': <gensim.models.keyedvectors.Vocab at 0x7f5202eaa850>,
#  'steps': <gensim.models.keyedvectors.Vocab at 0x7f5202eaa8b0>,
#  'gate': <gensim.models.keyedvectors.Vocab at 0x7f5202eaa910>,
#  'stay': <gensim.models.keyedvectors.Vocab at 0x7f5202eaa970>,
#  'true': <gensim.models.keyedvectors.Vocab at 0x7f5202eaa9d0>,
#  'wind': <gensim.models.keyedvectors.Vocab at 0x7f5202eaaa30>,
#  'many': <gensim.models.keyedvectors.Vocab at 0x7f5202eaaa90>,
#  'text': <gensim.models.keyedvectors.Vocab at 0x7f5202eaaaf0>,
#  'mere': <gensim.models.keyedvectors.Vocab at 0x7f5202eaab50>,
#  'belanja': <gensim.models.keyedvectors.Vocab at 0x7f5202eaabb0>,
#  'negeri': <gensim.models.keyedvectors.Vocab at 0x7f5202eaac10>,
#  'wine': <gensim.models.keyedvectors.Vocab at 0x7f5202eaac70>,
#  'loan': <gensim.models.keyedvectors.Vocab at 0x7f5202eaacd0>,
#  'pooh': <gensim.models.keyedvectors.Vocab at 0x7f5202eaad30>,
#  'terang': <gensim.models.keyedvectors.Vocab at 0x7f5202eaad90>,
#  'without': <gensim.models.keyedvectors.Vocab at 0x7f5202eaadf0>,
# ...
#  'thank': <gensim.models.keyedvectors.Vocab at 0x7f5202eaafd0>,
#  'call': <gensim.models.keyedvectors.Vocab at 0x7f5202ead070>,
#  'rale': <gensim.models.keyedvectors.Vocab at 0x7f5202ead0d0>,
#  'sorry': <gensim.models.keyedvectors.Vocab at 0x7f5202ead130>,
#  'late': <gensim.models.keyedvectors.Vocab at 0x7f5202ead190>,
#  'want': <gensim.models.keyedvectors.Vocab at 0x7f5202ead1f0>,
#  'bell': <gensim.models.keyedvectors.Vocab at 0x7f5202ead250>,
#  'pesi': <gensim.models.keyedvectors.Vocab at 0x7f5202ead2b0>,
#  'college': <gensim.models.keyedvectors.Vocab at 0x7f5202ead310>,
#  'balm': <gensim.models.keyedvectors.Vocab at 0x7f5202ead370>,
#  'louis': <gensim.models.keyedvectors.Vocab at 0x7f5202ead3d0>,
#  'space': <gensim.models.keyedvectors.Vocab at 0x7f5202ead430>,
#  'salt': <gensim.models.keyedvectors.Vocab at 0x7f5202ead490>,
#  'potato': <gensim.models.keyedvectors.Vocab at 0x7f5202ead4f0>,
#  'pepe': <gensim.models.keyedvectors.Vocab at 0x7f5202ead550>,
#  'cooked': <gensim.models.keyedvectors.Vocab at 0x7f5202ead5b0>,
#  'chips': <gensim.models.keyedvectors.Vocab at 0x7f5202ead610>,
#  'onion': <gensim.models.keyedvectors.Vocab at 0x7f5202ead670>,
#  'nature': <gensim.models.keyedvectors.Vocab at 0x7f5202ead6d0>,
#  'spring': <gensim.models.keyedvectors.Vocab at 0x7f5202ead730>,
#  'error': <gensim.models.keyedvectors.Vocab at 0x7f5202ead790>,
#  'perbedaan': <gensim.models.keyedvectors.Vocab at 0x7f5202ead7f0>,
#  'soon': <gensim.models.keyedvectors.Vocab at 0x7f5202ead850>,
#  'beauty': <gensim.models.keyedvectors.Vocab at 0x7f5202ead8b0>,
#  'cine': <gensim.models.keyedvectors.Vocab at 0x7f5202ead910>,
#  'wool': <gensim.models.keyedvectors.Vocab at 0x7f5202ead970>,
#  'soft': <gensim.models.keyedvectors.Vocab at 0x7f5202ead9d0>,
#  'toilet': <gensim.models.keyedvectors.Vocab at 0x7f5202eada30>,
#  'company': <gensim.models.keyedvectors.Vocab at 0x7f5202eada90>,
#  'case': <gensim.models.keyedvectors.Vocab at 0x7f5202eadaf0>,
#  'pins': <gensim.models.keyedvectors.Vocab at 0x7f5202eadb50>,
#  'alis': <gensim.models.keyedvectors.Vocab at 0x7f5202eadbb0>,
#  'herbal': <gensim.models.keyedvectors.Vocab at 0x7f5202eadc10>,
#  'cross': <gensim.models.keyedvectors.Vocab at 0x7f5202eadc70>,
#  'product': <gensim.models.keyedvectors.Vocab at 0x7f5202eadcd0>,
#  'mean': <gensim.models.keyedvectors.Vocab at 0x7f5202eadd30>,
#  'printing': <gensim.models.keyedvectors.Vocab at 0x7f5202eadd90>,
#  'sports': <gensim.models.keyedvectors.Vocab at 0x7f5202eaddf0>,
#  'star': <gensim.models.keyedvectors.Vocab at 0x7f5202eade50>,
#  'polyester': <gensim.models.keyedvectors.Vocab at 0x7f5202eadeb0>,
#  'inch': <gensim.models.keyedvectors.Vocab at 0x7f5202eadf10>,
#  'fight': <gensim.models.keyedvectors.Vocab at 0x7f5202eadf70>,
#  'know': <gensim.models.keyedvectors.Vocab at 0x7f5202eadfd0>,
#  'already': <gensim.models.keyedvectors.Vocab at 0x7f5202eaf070>,
#  'really': <gensim.models.keyedvectors.Vocab at 0x7f5202eaf0d0>,
#  'lose': <gensim.models.keyedvectors.Vocab at 0x7f5202eaf130>,
#  'central': <gensim.models.keyedvectors.Vocab at 0x7f5202eaf190>,
#  'jaring': <gensim.models.keyedvectors.Vocab at 0x7f5202eaf1f0>,
#  'erie': <gensim.models.keyedvectors.Vocab at 0x7f5202eaf250>,
#  'shut': <gensim.models.keyedvectors.Vocab at 0x7f5202eaf2b0>,
#  'cable': <gensim.models.keyedvectors.Vocab at 0x7f5202eaf310>,
#  'wana': <gensim.models.keyedvectors.Vocab at 0x7f5202eaf370>,
#  'discover': <gensim.models.keyedvectors.Vocab at 0x7f5202eaf3d0>,
#  'collar': <gensim.models.keyedvectors.Vocab at 0x7f5202eaf430>,
#  'helps': <gensim.models.keyedvectors.Vocab at 0x7f5202eaf490>,
#  'codes': <gensim.models.keyedvectors.Vocab at 0x7f5202eaf4f0>,
#  'soda': <gensim.models.keyedvectors.Vocab at 0x7f5202eaf550>,
#  'ending': <gensim.models.keyedvectors.Vocab at 0x7f5202eaf5b0>,
#  'lemon': <gensim.models.keyedvectors.Vocab at 0x7f5202eaf610>,
#  'waste': <gensim.models.keyedvectors.Vocab at 0x7f5202eaf670>,
#  'land': <gensim.models.keyedvectors.Vocab at 0x7f5202eaf6d0>,
#  'miles': <gensim.models.keyedvectors.Vocab at 0x7f5202eaf730>,
#  'supplier': <gensim.models.keyedvectors.Vocab at 0x7f5202eaf790>,
#  'camel': <gensim.models.keyedvectors.Vocab at 0x7f5202eaf7f0>,
#  'dian': <gensim.models.keyedvectors.Vocab at 0x7f5202eaf850>,
#  'online': <gensim.models.keyedvectors.Vocab at 0x7f5202eaf8b0>,
#  'always': <gensim.models.keyedvectors.Vocab at 0x7f5202eaf910>,
#  'seal': <gensim.models.keyedvectors.Vocab at 0x7f5202eaf970>,
#  'favorite': <gensim.models.keyedvectors.Vocab at 0x7f5202eaf9d0>,
#  'model': <gensim.models.keyedvectors.Vocab at 0x7f5202eafa30>,
#  'ulen': <gensim.models.keyedvectors.Vocab at 0x7f5202eafa90>,
#  'media': <gensim.models.keyedvectors.Vocab at 0x7f5202eafaf0>,
#  'label': <gensim.models.keyedvectors.Vocab at 0x7f5202eafb50>,
#  'everyone': <gensim.models.keyedvectors.Vocab at 0x7f5202eafbb0>,
#  'class': <gensim.models.keyedvectors.Vocab at 0x7f5202eafc10>,
#  'image': <gensim.models.keyedvectors.Vocab at 0x7f5202eafc70>,
#  'bunny': <gensim.models.keyedvectors.Vocab at 0x7f5202eafcd0>,
#  'leas': <gensim.models.keyedvectors.Vocab at 0x7f5202eafd30>,
#  'teeth': <gensim.models.keyedvectors.Vocab at 0x7f5202eafd90>,
#  'shin': <gensim.models.keyedvectors.Vocab at 0x7f5202eafdf0>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x7f5202eafe50>,
#  'member': <gensim.models.keyedvectors.Vocab at 0x7f5202eafeb0>,
#  'idea': <gensim.models.keyedvectors.Vocab at 0x7f5202eaff10>,
#  'hore': <gensim.models.keyedvectors.Vocab at 0x7f5202eaff70>,
#  'loose': <gensim.models.keyedvectors.Vocab at 0x7f5202eaffd0>,
#  'petite': <gensim.models.keyedvectors.Vocab at 0x7f5202eb0070>,
#  'elegant': <gensim.models.keyedvectors.Vocab at 0x7f5202eb00d0>,
#  'curve': <gensim.models.keyedvectors.Vocab at 0x7f5202eb0130>,
#  'neck': <gensim.models.keyedvectors.Vocab at 0x7f5202eb0190>,
#  'sexy': <gensim.models.keyedvectors.Vocab at 0x7f5202eb01f0>,
#  'happiness': <gensim.models.keyedvectors.Vocab at 0x7f5202eb0250>,
#  'destiny': <gensim.models.keyedvectors.Vocab at 0x7f5202eb02b0>,
#  'bolu': <gensim.models.keyedvectors.Vocab at 0x7f5202eb0310>,
#  'reta': <gensim.models.keyedvectors.Vocab at 0x7f5202eb0370>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x7f5202eb03d0>,
#  'mickey': <gensim.models.keyedvectors.Vocab at 0x7f5202eb0430>,
#  'american': <gensim.models.keyedvectors.Vocab at 0x7f5202eb0490>,
#  'adventure': <gensim.models.keyedvectors.Vocab at 0x7f5202eb04f0>,
#  'anon': <gensim.models.keyedvectors.Vocab at 0x7f5202eb0550>,
#  'son': <gensim.models.keyedvectors.Vocab at 0x7f5202eb05b0>,
#  'hotel': <gensim.models.keyedvectors.Vocab at 0x7f5202eb0610>,
#  'palace': <gensim.models.keyedvectors.Vocab at 0x7f5202eb0670>,
#  'pacific': <gensim.models.keyedvectors.Vocab at 0x7f5202eb06d0>,
#  'south': <gensim.models.keyedvectors.Vocab at 0x7f5202eb0730>,
#  'grand': <gensim.models.keyedvectors.Vocab at 0x7f5202eb0790>,
#  'bora': <gensim.models.keyedvectors.Vocab at 0x7f5202eb07f0>,
#  'garmen': <gensim.models.keyedvectors.Vocab at 0x7f5202eb0850>,
#  'supermarket': <gensim.models.keyedvectors.Vocab at 0x7f5202eb08b0>,
#  'service': <gensim.models.keyedvectors.Vocab at 0x7f5202eb0910>,
#  'stoner': <gensim.models.keyedvectors.Vocab at 0x7f5202eb0970>,
#  'mill': <gensim.models.keyedvectors.Vocab at 0x7f5202eb09d0>,
#  'hours': <gensim.models.keyedvectors.Vocab at 0x7f5202eb0a30>,
#  'roasted': <gensim.models.keyedvectors.Vocab at 0x7f5202eb0a90>,
#  'bran': <gensim.models.keyedvectors.Vocab at 0x7f5202eb0af0>,
#  'fake': <gensim.models.keyedvectors.Vocab at 0x7f5202eb0b50>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x7f5202eb0bb0>,
#  'dale': <gensim.models.keyedvectors.Vocab at 0x7f5202eb0c10>,
#  'sols': <gensim.models.keyedvectors.Vocab at 0x7f5202eb0c70>,
#  'sleep': <gensim.models.keyedvectors.Vocab at 0x7f5202eb0cd0>,
#  'travel': <gensim.models.keyedvectors.Vocab at 0x7f5202eb0d30>,
#  'repeat': <gensim.models.keyedvectors.Vocab at 0x7f5202eb0d90>,
#  'tricks': <gensim.models.keyedvectors.Vocab at 0x7f5202eb0df0>,
#  'iron': <gensim.models.keyedvectors.Vocab at 0x7f5202eb0e50>,
#  'fire': <gensim.models.keyedvectors.Vocab at 0x7f5202eb0eb0>,
#  'number': <gensim.models.keyedvectors.Vocab at 0x7f5202eb0f10>,
#  'lone': <gensim.models.keyedvectors.Vocab at 0x7f5202eb0f70>,
#  'action': <gensim.models.keyedvectors.Vocab at 0x7f5202eb0fd0>,
#  'coll': <gensim.models.keyedvectors.Vocab at 0x7f5202eb3070>,
#  'beautiful': <gensim.models.keyedvectors.Vocab at 0x7f5202eb30d0>,
#  'mule': <gensim.models.keyedvectors.Vocab at 0x7f5202eb3130>,
#  'orel': <gensim.models.keyedvectors.Vocab at 0x7f5202eb3190>,
#  'den': <gensim.models.keyedvectors.Vocab at 0x7f5202eb31f0>,
#  'james': <gensim.models.keyedvectors.Vocab at 0x7f5202eb3250>,
#  'loss': <gensim.models.keyedvectors.Vocab at 0x7f5202eb32b0>,
#  'prom': <gensim.models.keyedvectors.Vocab at 0x7f5202eb3310>,
#  'terry': <gensim.models.keyedvectors.Vocab at 0x7f5202eb3370>,
#  'global': <gensim.models.keyedvectors.Vocab at 0x7f5202eb33d0>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x7f5202eb3430>,
#  'code': <gensim.models.keyedvectors.Vocab at 0x7f5202eb3490>,
#  'cloth': <gensim.models.keyedvectors.Vocab at 0x7f5202eb34f0>,
#  'dies': <gensim.models.keyedvectors.Vocab at 0x7f5202eb3550>,
#  'berry': <gensim.models.keyedvectors.Vocab at 0x7f5202eb35b0>,
#  'lingkaran': <gensim.models.keyedvectors.Vocab at 0x7f5202eb3610>,
#  'tren': <gensim.models.keyedvectors.Vocab at 0x7f5202eb3670>,
#  'book': <gensim.models.keyedvectors.Vocab at 0x7f5202eb36d0>,
#  'night': <gensim.models.keyedvectors.Vocab at 0x7f5202eb3730>,
#  'axis': <gensim.models.keyedvectors.Vocab at 0x7f5202eb3790>,
#  'wens': <gensim.models.keyedvectors.Vocab at 0x7f5202eb37f0>,
#  'nones': <gensim.models.keyedvectors.Vocab at 0x7f5202eb3850>,
#  'cate': <gensim.models.keyedvectors.Vocab at 0x7f5202eb38b0>,
#  'bestseller': <gensim.models.keyedvectors.Vocab at 0x7f5202eb3910>,
#  'cash': <gensim.models.keyedvectors.Vocab at 0x7f5202eb3970>,
#  'cool': <gensim.models.keyedvectors.Vocab at 0x7f5202eb39d0>,
#  'help': <gensim.models.keyedvectors.Vocab at 0x7f5202eb3a30>,
#  'remember': <gensim.models.keyedvectors.Vocab at 0x7f5202eb3a90>,
#  'vans': <gensim.models.keyedvectors.Vocab at 0x7f5202eb3af0>,
#  'blouse': <gensim.models.keyedvectors.Vocab at 0x7f5202eb3b50>,
#  'hood': <gensim.models.keyedvectors.Vocab at 0x7f5202eb3bb0>,
#  'pile': <gensim.models.keyedvectors.Vocab at 0x7f5202eb3c10>,
#  'footwear': <gensim.models.keyedvectors.Vocab at 0x7f5202eb3c70>,
#  'today': <gensim.models.keyedvectors.Vocab at 0x7f5202eb3cd0>,
#  'ells': <gensim.models.keyedvectors.Vocab at 0x7f5202eb3d30>,
#  'bale': <gensim.models.keyedvectors.Vocab at 0x7f5202eb3d90>,
#  'state': <gensim.models.keyedvectors.Vocab at 0x7f5202eb3df0>,
#  'mind': <gensim.models.keyedvectors.Vocab at 0x7f5202eb3e50>,
#  'foil': <gensim.models.keyedvectors.Vocab at 0x7f5202eb3eb0>,
#  'arms': <gensim.models.keyedvectors.Vocab at 0x7f5202eb3f10>,
#  'yesterday': <gensim.models.keyedvectors.Vocab at 0x7f5202eb3f70>,
#  'alit': <gensim.models.keyedvectors.Vocab at 0x7f5202eb3fd0>,
#  'local': <gensim.models.keyedvectors.Vocab at 0x7f5202eb5070>,
#  'daily': <gensim.models.keyedvectors.Vocab at 0x7f5202eb50d0>,
#  'melting': <gensim.models.keyedvectors.Vocab at 0x7f5202eb5130>,
#  'cone': <gensim.models.keyedvectors.Vocab at 0x7f5202eb5190>,
#  'table': <gensim.models.keyedvectors.Vocab at 0x7f5202eb51f0>,
#  'getting': <gensim.models.keyedvectors.Vocab at 0x7f5202eb5250>,
#  'makes': <gensim.models.keyedvectors.Vocab at 0x7f5202eb52b0>,
#  'cat': <gensim.models.keyedvectors.Vocab at 0x7f5202eb5310>,
#  'dodo': <gensim.models.keyedvectors.Vocab at 0x7f5202eb5370>,
#  'thin': <gensim.models.keyedvectors.Vocab at 0x7f5202eb53d0>,
#  'motor': <gensim.models.keyedvectors.Vocab at 0x7f5202eb5430>,
#  'cycle': <gensim.models.keyedvectors.Vocab at 0x7f5202eb5490>,
#  'tide': <gensim.models.keyedvectors.Vocab at 0x7f5202eb54f0>,
#  'station': <gensim.models.keyedvectors.Vocab at 0x7f5202eb5550>,
#  'tasa': <gensim.models.keyedvectors.Vocab at 0x7f5202eb55b0>,
#  'sone': <gensim.models.keyedvectors.Vocab at 0x7f5202eb5610>,
#  'water': <gensim.models.keyedvectors.Vocab at 0x7f5202eb5670>,
#  'handy': <gensim.models.keyedvectors.Vocab at 0x7f5202eb56d0>,
#  'print': <gensim.models.keyedvectors.Vocab at 0x7f5202eb5730>,
#  'plans': <gensim.models.keyedvectors.Vocab at 0x7f5202eb5790>,
#  'country': <gensim.models.keyedvectors.Vocab at 0x7f5202eb57f0>,
#  'fabric': <gensim.models.keyedvectors.Vocab at 0x7f5202eb5850>,
#  'awesome': <gensim.models.keyedvectors.Vocab at 0x7f5202eb58b0>,
#  'catur': <gensim.models.keyedvectors.Vocab at 0x7f5202eb5910>,
#  'ripped': <gensim.models.keyedvectors.Vocab at 0x7f5202eb5970>,
#  'pencil': <gensim.models.keyedvectors.Vocab at 0x7f5202eb59d0>,
#  'washed': <gensim.models.keyedvectors.Vocab at 0x7f5202eb5a30>,
#  'jeans': <gensim.models.keyedvectors.Vocab at 0x7f5202eb5a90>,
#  'karet': <gensim.models.keyedvectors.Vocab at 0x7f5202eb5af0>,
#  'pinggang': <gensim.models.keyedvectors.Vocab at 0x7f5202eb5b50>,
#  'aplikasi': <gensim.models.keyedvectors.Vocab at 0x7f5202eb5bb0>,
#  'baret': <gensim.models.keyedvectors.Vocab at 0x7f5202eb5c10>,
#  'hipster': <gensim.models.keyedvectors.Vocab at 0x7f5202eb5c70>,
#  'matte': <gensim.models.keyedvectors.Vocab at 0x7f5202eb5cd0>,
#  'wild': <gensim.models.keyedvectors.Vocab at 0x7f5202eb5d30>,
#  'lord': <gensim.models.keyedvectors.Vocab at 0x7f5202eb5d90>,
#  'acid': <gensim.models.keyedvectors.Vocab at 0x7f5202eb5df0>,
#  'sobek': <gensim.models.keyedvectors.Vocab at 0x7f5202eb5e50>,
#  'lapis': <gensim.models.keyedvectors.Vocab at 0x7f5202eb5eb0>,
#  'willow': <gensim.models.keyedvectors.Vocab at 0x7f5202eb5f10>,
#  'normal': <gensim.models.keyedvectors.Vocab at 0x7f5202eb5f70>,
#  'knee': <gensim.models.keyedvectors.Vocab at 0x7f5202eb5fd0>,
#  'lipatan': <gensim.models.keyedvectors.Vocab at 0x7f5202eb6070>,
#  'dibuka': <gensim.models.keyedvectors.Vocab at 0x7f5202eb60d0>,
#  'tembus': <gensim.models.keyedvectors.Vocab at 0x7f5202eb6130>,
#  'sobekan': <gensim.models.keyedvectors.Vocab at 0x7f5202eb6190>,
#  'melar': <gensim.models.keyedvectors.Vocab at 0x7f5202eb61f0>,
#  'logo': <gensim.models.keyedvectors.Vocab at 0x7f5202eb6250>,
#  'jerry': <gensim.models.keyedvectors.Vocab at 0x7f5202eb62b0>,
#  'snow': <gensim.models.keyedvectors.Vocab at 0x7f5202eb6310>,
#  'waist': <gensim.models.keyedvectors.Vocab at 0x7f5202eb6370>,
#  'silet': <gensim.models.keyedvectors.Vocab at 0x7f5202eb63d0>,
#  'lapisan': <gensim.models.keyedvectors.Vocab at 0x7f5202eb6430>,
#  'colon': <gensim.models.keyedvectors.Vocab at 0x7f5202eb6490>,
#  'galea': <gensim.models.keyedvectors.Vocab at 0x7f5202eb64f0>,
#  'deep': <gensim.models.keyedvectors.Vocab at 0x7f5202eb6550>,
#  'seem': <gensim.models.keyedvectors.Vocab at 0x7f5202eb65b0>,
#  'cakar': <gensim.models.keyedvectors.Vocab at 0x7f5202eb6610>,
#  'hips': <gensim.models.keyedvectors.Vocab at 0x7f5202eb6670>,
#  'skinny': <gensim.models.keyedvectors.Vocab at 0x7f5202eb66d0>,
#  'olla': <gensim.models.keyedvectors.Vocab at 0x7f5202eb6730>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x7f5202eb6790>,
#  'coder': <gensim.models.keyedvectors.Vocab at 0x7f5202eb67f0>,
#  'sizer': <gensim.models.keyedvectors.Vocab at 0x7f5202eb6850>,
#  'deans': <gensim.models.keyedvectors.Vocab at 0x7f5202eb68b0>,
#  'group': <gensim.models.keyedvectors.Vocab at 0x7f5202eb6910>,
#  'oily': <gensim.models.keyedvectors.Vocab at 0x7f5202eb6970>,
#  'tambal': <gensim.models.keyedvectors.Vocab at 0x7f5202eb69d0>,
#  'celana': <gensim.models.keyedvectors.Vocab at 0x7f5202eb6a30>,
#  'left': <gensim.models.keyedvectors.Vocab at 0x7f5202eb6a90>,
#  'rumbai': <gensim.models.keyedvectors.Vocab at 0x7f5202eb6af0>,
#  'cari': <gensim.models.keyedvectors.Vocab at 0x7f5202eb6b50>,
#  'pinggul': <gensim.models.keyedvectors.Vocab at 0x7f5202eb6bb0>,
#  'paha': <gensim.models.keyedvectors.Vocab at 0x7f5202eb6c10>,
#  'umbo': <gensim.models.keyedvectors.Vocab at 0x7f5202eb6c70>,
#  'caca': <gensim.models.keyedvectors.Vocab at 0x7f5202eb6cd0>,
#  'coach': <gensim.models.keyedvectors.Vocab at 0x7f5202eb6d30>,
#  'nyaman': <gensim.models.keyedvectors.Vocab at 0x7f5202eb6d90>,
#  'obey': <gensim.models.keyedvectors.Vocab at 0x7f5202eb6df0>,
#  'ill': <gensim.models.keyedvectors.Vocab at 0x7f5202eb6e50>,
#  ...}

# %% [markdown]
# # Convert Dataset

# %%
def create_embedding_vectors(model_ft):
    vocab_size = len(model_ft.wv.vocab) + 2
    embedding_vectors = np.zeros((vocab_size, EMBEDDING_DIMENSION))

    vocab_list = list(model_ft.wv.vocab)
    for i in range(vocab_size - 2):
        current_vocab = vocab_list[i]
        index = model_ft.wv.vocab[current_vocab].index

        embedding_vectors[index] = model_ft.wv[current_vocab]

    return vocab_size, embedding_vectors

from tensorflow.keras.preprocessing.sequence import pad_sequences

def sentence_to_index(sentence, model_ft):
    new_sentence = []
    for word in sentence:
        try:
            new_sentence.append(model_ft.wv.vocab[word].index)
        except:
            new_sentence.append(vocab_size - 2)  # vocab_size - 2 : unseen words
    
    return new_sentence

def sentences_to_sequences(model_ft, X):
    for i in range(len(X)):
        X[i] = sentence_to_index(X[i], model_ft)
    X_seq = pad_sequences(X, value=vocab_size-1, maxlen=MAX_WORD, padding='post')  # vocab_size - 1 : empty / padding

    return X_seq

# %%
vocab_size, embedding_vectors = create_embedding_vectors(model_ft)
X_train_seq = sentences_to_sequences(model_ft, X_train)
X_test_seq = sentences_to_sequences(model_ft, X_test)

# %% [markdown]
# # Model functions

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Activation, BatchNormalization, Embedding, Bidirectional, LSTM, GlobalAveragePooling1D
from attention import attention_3d_block

def test_model(model, X_test, y_test, filename):
    global df_test
    y_pred = model.predict(X_test)
    y_pred = np.argmax(y_pred, axis=-1)

    # f1 = f1_score(y_test, y_pred, average='weighted')
    # print('Weighted F1 Score:', f1)

    # print('Classification Report:')
    # print(classification_report(y_test, y_pred))

    test_ids = df_test['filename'].to_numpy()

    np.savetxt(filename, np.rec.fromarrays([test_ids, y_pred]), fmt=['%s', '%02d'], delimiter=',', header='filename,category', comments='')

def compile_model(model):
    model.compile(
    optimizer=tfa.optimizers.RectifiedAdam(
        lr=0.1,
        total_steps=50,
        warmup_proportion=0.1,
        min_lr=0.02,
    ),
    loss='sparse_categorical_crossentropy',
    metrics=['sparse_categorical_accuracy'])
    return model

# %% [markdown]
# # FastText + Bi-LSTM + Many-to-one attention mechanism

# %%
m_input = Input(shape=(MAX_WORD, ), name='input')
x = Embedding(input_dim=vocab_size, output_dim=EMBEDDING_DIMENSION, input_length=MAX_WORD, weights=[embedding_vectors], trainable=False, name='embedding')(m_input)
x = Bidirectional(LSTM(units=32, return_sequences=True, name='lstm'), name='bi-directional')(x)
# x = GlobalAveragePooling1D(name='global-average-pooling-1d')(x)
x = attention_3d_block(x)
m_output = Dense(42, name='output', activation='softmax')(x)
modelft2 = tf.keras.Model(inputs=m_input, outputs=m_output)

compile_model(modelft2)
modelft2.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 200)]        0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 200, 30)      199050      input[0][0]
# __________________________________________________________________________________________________
# bi-directional (Bidirectional)  (None, 200, 64)      16128       embedding[0][0]
# __________________________________________________________________________________________________
# attention_score_vec (Dense)     (None, 200, 64)      4096        bi-directional[0][0]
# __________________________________________________________________________________________________
# last_hidden_state (Lambda)      (None, 64)           0           bi-directional[0][0]
# __________________________________________________________________________________________________
# attention_score (Dot)           (None, 200)          0           attention_score_vec[0][0]
#                                                                  last_hidden_state[0][0]
# __________________________________________________________________________________________________
# attention_weight (Activation)   (None, 200)          0           attention_score[0][0]
# __________________________________________________________________________________________________
# context_vector (Dot)            (None, 64)           0           bi-directional[0][0]
#                                                                  attention_weight[0][0]
# __________________________________________________________________________________________________
# attention_output (Concatenate)  (None, 128)          0           context_vector[0][0]
#                                                                  last_hidden_state[0][0]
# __________________________________________________________________________________________________
# attention_vector (Dense)        (None, 128)          16384       attention_output[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 42)           5418        attention_vector[0][0]
# ==================================================================================================
# Total params: 241,076
# Trainable params: 42,026
# Non-trainable params: 199,050
# __________________________________________________________________________________________________

# %%
modelft2.fit(X_train_seq, y_train, batch_size=1000, epochs=50, verbose=1)
# Out:
# Epoch 1/50
# 106/106 [==============================] - 7s 70ms/step - loss: 3.2010 - sparse_categorical_accuracy: 0.1738
# Epoch 2/50
# 106/106 [==============================] - 7s 70ms/step - loss: 2.9553 - sparse_categorical_accuracy: 0.2340
# Epoch 3/50
# 106/106 [==============================] - 8s 71ms/step - loss: 2.9056 - sparse_categorical_accuracy: 0.2470
# Epoch 4/50
# 106/106 [==============================] - 8s 71ms/step - loss: 2.8714 - sparse_categorical_accuracy: 0.2538
# Epoch 5/50
# 106/106 [==============================] - 7s 71ms/step - loss: 2.8484 - sparse_categorical_accuracy: 0.2592
# Epoch 6/50
# 106/106 [==============================] - 7s 70ms/step - loss: 2.8300 - sparse_categorical_accuracy: 0.2640
# Epoch 7/50
# 106/106 [==============================] - 7s 69ms/step - loss: 2.8156 - sparse_categorical_accuracy: 0.2661
# Epoch 8/50
# 106/106 [==============================] - 7s 68ms/step - loss: 2.8059 - sparse_categorical_accuracy: 0.2687
# Epoch 9/50
# 106/106 [==============================] - 7s 68ms/step - loss: 2.7919 - sparse_categorical_accuracy: 0.2706
# Epoch 10/50
# 106/106 [==============================] - 7s 68ms/step - loss: 2.7856 - sparse_categorical_accuracy: 0.2727
# Epoch 11/50
# 106/106 [==============================] - 7s 68ms/step - loss: 2.7735 - sparse_categorical_accuracy: 0.2751
# Epoch 12/50
# 106/106 [==============================] - 7s 68ms/step - loss: 2.7655 - sparse_categorical_accuracy: 0.2764
# Epoch 13/50
# 106/106 [==============================] - 7s 67ms/step - loss: 2.7567 - sparse_categorical_accuracy: 0.2792
# Epoch 14/50
# 106/106 [==============================] - 7s 68ms/step - loss: 2.7504 - sparse_categorical_accuracy: 0.2809
# Epoch 15/50
# 106/106 [==============================] - 7s 68ms/step - loss: 2.7436 - sparse_categorical_accuracy: 0.2818
# Epoch 16/50
# 106/106 [==============================] - 7s 68ms/step - loss: 2.7398 - sparse_categorical_accuracy: 0.2822
# Epoch 17/50
# 106/106 [==============================] - 7s 68ms/step - loss: 2.7329 - sparse_categorical_accuracy: 0.2838
# Epoch 18/50
# 106/106 [==============================] - 7s 67ms/step - loss: 2.7270 - sparse_categorical_accuracy: 0.2841
# Epoch 19/50
# 106/106 [==============================] - 7s 68ms/step - loss: 2.7204 - sparse_categorical_accuracy: 0.2864
# Epoch 20/50
# 106/106 [==============================] - 7s 68ms/step - loss: 2.7230 - sparse_categorical_accuracy: 0.2851
# Epoch 21/50
# 106/106 [==============================] - 7s 68ms/step - loss: 2.7149 - sparse_categorical_accuracy: 0.2863
# Epoch 22/50
# 106/106 [==============================] - 7s 68ms/step - loss: 2.7103 - sparse_categorical_accuracy: 0.2875
# Epoch 23/50
# 106/106 [==============================] - 7s 67ms/step - loss: 2.7033 - sparse_categorical_accuracy: 0.2902
# Epoch 24/50
# 106/106 [==============================] - 7s 68ms/step - loss: 2.6987 - sparse_categorical_accuracy: 0.2911
# Epoch 25/50
# 106/106 [==============================] - 7s 68ms/step - loss: 2.6991 - sparse_categorical_accuracy: 0.2905
# Epoch 26/50
# 106/106 [==============================] - 7s 68ms/step - loss: 2.7001 - sparse_categorical_accuracy: 0.2909
# Epoch 27/50
# 106/106 [==============================] - 7s 68ms/step - loss: 2.6944 - sparse_categorical_accuracy: 0.2916
# Epoch 28/50
# 106/106 [==============================] - 7s 68ms/step - loss: 2.6897 - sparse_categorical_accuracy: 0.2923
# Epoch 29/50
# 106/106 [==============================] - 7s 68ms/step - loss: 2.6898 - sparse_categorical_accuracy: 0.2922
# Epoch 30/50
# 106/106 [==============================] - 7s 68ms/step - loss: 2.6849 - sparse_categorical_accuracy: 0.2931
# Epoch 31/50
# 106/106 [==============================] - 7s 68ms/step - loss: 2.6816 - sparse_categorical_accuracy: 0.2944
# Epoch 32/50
# 106/106 [==============================] - 7s 68ms/step - loss: 2.6821 - sparse_categorical_accuracy: 0.2946
# Epoch 33/50
# 106/106 [==============================] - 7s 68ms/step - loss: 2.6784 - sparse_categorical_accuracy: 0.2952
# Epoch 34/50
# 106/106 [==============================] - 7s 68ms/step - loss: 2.6765 - sparse_categorical_accuracy: 0.2941
# Epoch 35/50
# 106/106 [==============================] - 7s 68ms/step - loss: 2.6757 - sparse_categorical_accuracy: 0.2950
# Epoch 36/50
# 106/106 [==============================] - 7s 68ms/step - loss: 2.6749 - sparse_categorical_accuracy: 0.2956
# Epoch 37/50
# 106/106 [==============================] - 7s 68ms/step - loss: 2.6712 - sparse_categorical_accuracy: 0.2964
# Epoch 38/50
# 106/106 [==============================] - 7s 69ms/step - loss: 2.6710 - sparse_categorical_accuracy: 0.2965
# Epoch 39/50
# 106/106 [==============================] - 7s 68ms/step - loss: 2.6688 - sparse_categorical_accuracy: 0.2964
# Epoch 40/50
# 106/106 [==============================] - 7s 68ms/step - loss: 2.6708 - sparse_categorical_accuracy: 0.2972
# Epoch 41/50
# 106/106 [==============================] - 7s 68ms/step - loss: 2.6687 - sparse_categorical_accuracy: 0.2967
# Epoch 42/50
# 106/106 [==============================] - 7s 68ms/step - loss: 2.6651 - sparse_categorical_accuracy: 0.2984
# Epoch 43/50
# 106/106 [==============================] - 7s 68ms/step - loss: 2.6606 - sparse_categorical_accuracy: 0.3000
# Epoch 44/50
# 106/106 [==============================] - 7s 68ms/step - loss: 2.6612 - sparse_categorical_accuracy: 0.2981
# Epoch 45/50
# 106/106 [==============================] - 7s 68ms/step - loss: 2.6575 - sparse_categorical_accuracy: 0.2995
# Epoch 46/50
# 106/106 [==============================] - 7s 68ms/step - loss: 2.6598 - sparse_categorical_accuracy: 0.2983
# Epoch 47/50
# 106/106 [==============================] - 7s 68ms/step - loss: 2.6757 - sparse_categorical_accuracy: 0.2944
# Epoch 48/50
# 106/106 [==============================] - 7s 68ms/step - loss: 2.6632 - sparse_categorical_accuracy: 0.2977
# Epoch 49/50
# 106/106 [==============================] - 7s 69ms/step - loss: 2.6588 - sparse_categorical_accuracy: 0.2989
# Epoch 50/50
# 106/106 [==============================] - 8s 75ms/step - loss: 2.6581 - sparse_categorical_accuracy: 0.2992

# %%
test_model(modelft2, X_test_seq, y_test, 'modelft2.csv')

# %% [markdown]
# # FastText + Bi-LSTM

# %%
m_input = Input(shape=(MAX_WORD, ), name='input')
x = Embedding(input_dim=vocab_size, output_dim=EMBEDDING_DIMENSION, input_length=MAX_WORD, weights=[embedding_vectors], trainable=False, name='embedding')(m_input)
x = Bidirectional(LSTM(units=32, return_sequences=False, name='lstm'), name='bi-directional')(x)
# x = GlobalAveragePooling1D(name='global-average-pooling-1d')(x)
# x = attention_3d_block(x)
m_output = Dense(42, name='output', activation='softmax')(x)
modelft3 = tf.keras.Model(inputs=m_input, outputs=m_output)

compile_model(modelft3)
modelft3.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 200)]             0
# _________________________________________________________________
# embedding (Embedding)        (None, 200, 30)           199050
# _________________________________________________________________
# bi-directional (Bidirectiona (None, 64)                16128
# _________________________________________________________________
# output (Dense)               (None, 42)                2730
# =================================================================
# Total params: 217,908
# Trainable params: 18,858
# Non-trainable params: 199,050
# _________________________________________________________________

# %%
modelft3.fit(X_train_seq, y_train, batch_size=1000, epochs=50, verbose=1)
# Out:
# Epoch 1/50
# 106/106 [==============================] - 5s 50ms/step - loss: 3.2938 - sparse_categorical_accuracy: 0.1567
# Epoch 2/50
# 106/106 [==============================] - 5s 50ms/step - loss: 3.0397 - sparse_categorical_accuracy: 0.2159
# Epoch 3/50
# 106/106 [==============================] - 5s 50ms/step - loss: 2.9827 - sparse_categorical_accuracy: 0.2297
# Epoch 4/50
# 106/106 [==============================] - 5s 50ms/step - loss: 2.9513 - sparse_categorical_accuracy: 0.2386
# Epoch 5/50
# 106/106 [==============================] - 5s 49ms/step - loss: 2.9304 - sparse_categorical_accuracy: 0.2425
# Epoch 6/50
# 106/106 [==============================] - 5s 49ms/step - loss: 2.9154 - sparse_categorical_accuracy: 0.2464
# Epoch 7/50
# 106/106 [==============================] - 5s 50ms/step - loss: 2.9048 - sparse_categorical_accuracy: 0.2483
# Epoch 8/50
# 106/106 [==============================] - 5s 49ms/step - loss: 2.8980 - sparse_categorical_accuracy: 0.2501
# Epoch 9/50
# 106/106 [==============================] - 5s 50ms/step - loss: 2.8906 - sparse_categorical_accuracy: 0.2518
# Epoch 10/50
# 106/106 [==============================] - 5s 49ms/step - loss: 2.8868 - sparse_categorical_accuracy: 0.2522
# Epoch 11/50
# 106/106 [==============================] - 5s 49ms/step - loss: 2.8807 - sparse_categorical_accuracy: 0.2536
# Epoch 12/50
# 106/106 [==============================] - 5s 49ms/step - loss: 2.8766 - sparse_categorical_accuracy: 0.2538
# Epoch 13/50
# 106/106 [==============================] - 5s 49ms/step - loss: 2.8734 - sparse_categorical_accuracy: 0.2551
# Epoch 14/50
# 106/106 [==============================] - 5s 50ms/step - loss: 2.8702 - sparse_categorical_accuracy: 0.2558
# Epoch 15/50
# 106/106 [==============================] - 5s 49ms/step - loss: 2.8671 - sparse_categorical_accuracy: 0.2573
# Epoch 16/50
# 106/106 [==============================] - 5s 49ms/step - loss: 2.8641 - sparse_categorical_accuracy: 0.2575
# Epoch 17/50
# 106/106 [==============================] - 5s 50ms/step - loss: 2.8639 - sparse_categorical_accuracy: 0.2565
# Epoch 18/50
# 106/106 [==============================] - 5s 49ms/step - loss: 2.8607 - sparse_categorical_accuracy: 0.2584
# Epoch 19/50
# 106/106 [==============================] - 5s 50ms/step - loss: 2.8605 - sparse_categorical_accuracy: 0.2577
# Epoch 20/50
# 106/106 [==============================] - 5s 51ms/step - loss: 2.8584 - sparse_categorical_accuracy: 0.2589
# Epoch 21/50
# 106/106 [==============================] - 5s 49ms/step - loss: 2.8563 - sparse_categorical_accuracy: 0.2583
# Epoch 22/50
# 106/106 [==============================] - 6s 53ms/step - loss: 2.8549 - sparse_categorical_accuracy: 0.2582
# Epoch 23/50
# 106/106 [==============================] - 5s 50ms/step - loss: 2.8558 - sparse_categorical_accuracy: 0.2590
# Epoch 24/50
# 106/106 [==============================] - 6s 52ms/step - loss: 2.8532 - sparse_categorical_accuracy: 0.2589
# Epoch 25/50
# 106/106 [==============================] - 5s 51ms/step - loss: 2.8542 - sparse_categorical_accuracy: 0.2591
# Epoch 26/50
# 106/106 [==============================] - 5s 51ms/step - loss: 2.8578 - sparse_categorical_accuracy: 0.2583
# Epoch 27/50
# 106/106 [==============================] - 5s 52ms/step - loss: 2.8517 - sparse_categorical_accuracy: 0.2587
# Epoch 28/50
# 106/106 [==============================] - 6s 52ms/step - loss: 2.8557 - sparse_categorical_accuracy: 0.2587
# Epoch 29/50
# 106/106 [==============================] - 5s 52ms/step - loss: 2.8506 - sparse_categorical_accuracy: 0.2609
# Epoch 30/50
# 106/106 [==============================] - 5s 52ms/step - loss: 2.8514 - sparse_categorical_accuracy: 0.2605
# Epoch 31/50
# 106/106 [==============================] - 5s 51ms/step - loss: 2.8616 - sparse_categorical_accuracy: 0.2575
# Epoch 32/50
# 106/106 [==============================] - 6s 52ms/step - loss: 2.8783 - sparse_categorical_accuracy: 0.2524
# Epoch 33/50
# 106/106 [==============================] - 6s 52ms/step - loss: 2.8654 - sparse_categorical_accuracy: 0.2560
# Epoch 34/50
# 106/106 [==============================] - 6s 52ms/step - loss: 2.8568 - sparse_categorical_accuracy: 0.2592
# Epoch 35/50
# 106/106 [==============================] - 6s 52ms/step - loss: 2.8653 - sparse_categorical_accuracy: 0.2569
# Epoch 36/50
# 106/106 [==============================] - 6s 53ms/step - loss: 2.8599 - sparse_categorical_accuracy: 0.2575
# Epoch 37/50
# 106/106 [==============================] - 6s 52ms/step - loss: 2.8577 - sparse_categorical_accuracy: 0.2579
# Epoch 38/50
# 106/106 [==============================] - 6s 53ms/step - loss: 2.8593 - sparse_categorical_accuracy: 0.2577
# Epoch 39/50
# 106/106 [==============================] - 6s 52ms/step - loss: 2.8567 - sparse_categorical_accuracy: 0.2598
# Epoch 40/50
# 106/106 [==============================] - 6s 53ms/step - loss: 2.8548 - sparse_categorical_accuracy: 0.2594
# Epoch 41/50
# 106/106 [==============================] - 6s 52ms/step - loss: 2.8554 - sparse_categorical_accuracy: 0.2576
# Epoch 42/50
# 106/106 [==============================] - 6s 52ms/step - loss: 2.8699 - sparse_categorical_accuracy: 0.2556
# Epoch 43/50
# 106/106 [==============================] - 6s 52ms/step - loss: 2.8765 - sparse_categorical_accuracy: 0.2528
# Epoch 44/50
# 106/106 [==============================] - 6s 53ms/step - loss: 2.8727 - sparse_categorical_accuracy: 0.2537
# Epoch 45/50
# 106/106 [==============================] - 6s 52ms/step - loss: 2.8593 - sparse_categorical_accuracy: 0.2566
# Epoch 46/50
# 106/106 [==============================] - 6s 53ms/step - loss: 2.8852 - sparse_categorical_accuracy: 0.2516
# Epoch 47/50
# 106/106 [==============================] - 6s 53ms/step - loss: 2.8753 - sparse_categorical_accuracy: 0.2544
# Epoch 48/50
# 106/106 [==============================] - 6s 53ms/step - loss: 2.8625 - sparse_categorical_accuracy: 0.2574
# Epoch 49/50
# 106/106 [==============================] - 6s 52ms/step - loss: 2.8698 - sparse_categorical_accuracy: 0.2555
# Epoch 50/50
# 106/106 [==============================] - 5s 51ms/step - loss: 2.8643 - sparse_categorical_accuracy: 0.2573

# %%
test_model(modelft3, X_test_seq, y_test, 'modelft3.csv')
